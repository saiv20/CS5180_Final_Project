# %%
import numpy as np
import torch
import copy
import torch.nn as nn
import torch.nn.functional as F

class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)
	

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.is_available())
print(torch.version.cuda)
print(device)

#Defining the Critic Network
class CriticNetwork(nn.Module):
	def __init__(self, state_dim, action_dim,hidden_layer_dim1=400,hidden_layer_dim2=300,learning_rate=1e-3):
		super(CriticNetwork, self).__init__()

		#Setting the dimensions of hidden layers. Paper default is 400 for layer 1 and 300 for layer 2
		self.hidden_layer1 = hidden_layer_dim1
		self.hidden_layer2 = hidden_layer_dim2

		#Depends on the environment
		self.state_dim = state_dim
		self.action_dim = action_dim

		#Q1 architecture
		self.Q1_fc1 = nn.Linear(self.state_dim + self.action_dim, self.hidden_layer1).to(device)
		self.Q1_fc2 = nn.Linear(self.hidden_layer1, self.hidden_layer2).to(device)
		self.Q1_out = nn.Linear(self.hidden_layer2, 1).to(device)

		# Q2 architecture
		self.Q2_fc1 = nn.Linear(self.state_dim + self.action_dim, self.hidden_layer1).to(device)
		self.Q2_fc2 = nn.Linear(self.hidden_layer1, self.hidden_layer2).to(device)
		self.Q2_out = nn.Linear(self.hidden_layer2, 1).to(device)

		self.critic_optimizer = torch.optim.Adam(self.parameters(), lr=learning_rate)


	def forward(self, state, action):
		sa = torch.cat([state, action], 1).to(device)

		q1 = F.relu(self.Q1_fc1(sa)).to(device)
		q1 = F.relu(self.Q1_fc2(q1)).to(device)
		q1 = self.Q1_out(q1).to(device)

		q2 = F.relu(self.Q2_fc1(sa)).to(device)
		q2 = F.relu(self.Q2_fc2(q2)).to(device)
		q2 = self.Q2_out(q2).to(device)
		return q1, q2


	def Q1(self, state, action):
		q1 = F.relu(self.Q1_fc1(torch.cat([state, action], 1)))
		q1 = F.relu(self.Q1_fc2(q1))
		q1 = self.Q1_out(q1)
		return q1

#Defining the Actor Network
class ActorNetwork(nn.Module):
	def __init__(self, state_dim, action_dim, max_action, hidden_layer_dim1=400,hidden_layer_dim2=300,learning_rate=1e-3):
		super(ActorNetwork, self).__init__()

		#Setting the dimensions of hidden layers. Paper default is 400 for layer 1 and 300 for layer 2
		self.hidden_layer1 = hidden_layer_dim1
		self.hidden_layer2 = hidden_layer_dim2
		self.max_action = max_action

		#Depends on the environment
		self.state_dim = state_dim
		self.action_dim = action_dim

		#Defining the network
		self.fc1 = nn.Linear(self.state_dim, self.hidden_layer1).to(device)
		self.fc2 = nn.Linear(self.hidden_layer1, self.hidden_layer2).to(device)
		self.act_out = nn.Linear(self.hidden_layer2, self.action_dim).to(device)

		#Defining the optimizer
		self.actor_optimizer = torch.optim.Adam(self.parameters(), lr=learning_rate)
		

	def forward(self, state):
		x = F.relu(self.fc1(state)).to(device)
		x = F.relu(self.fc2(x)).to(device)
		x = torch.tanh(self.act_out(x)).to(device)
		x = (self.max_action * x).to(device)
		return x
	

class TD3_Agent(object):
	def __init__(
		self,
		state_dim,
		action_dim,
		max_action,
		hidden_layer_dim1 = 400,
		hidden_layer_dim2 = 300,
		learning_rate = 1e-3,
		discount=0.99,
		tau=0.005,
		policy_noise=0.2,
		noise_clip=0.5,
		policy_freq=2
	):

		self.actor = ActorNetwork(state_dim, action_dim, max_action,hidden_layer_dim1,hidden_layer_dim2,learning_rate).to(device)
		self.actor_target = copy.deepcopy(self.actor)

		self.critic = CriticNetwork(state_dim, action_dim,hidden_layer_dim1,hidden_layer_dim2,learning_rate).to(device)
		self.critic_target = copy.deepcopy(self.critic)

		self.max_action = max_action
		self.discount = discount
		self.tau = tau
		self.policy_noise = policy_noise
		self.noise_clip = noise_clip
		self.policy_freq = policy_freq

		self.total_it = 0


	def select_action(self, state):
		state = torch.FloatTensor(state.reshape(1, -1)).to(device)
		return self.actor(state).cpu().data.numpy().flatten()


	def train(self, replay_buffer, batch_size=256):
		self.total_it += 1

		# Sample replay buffer 
		state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

		with torch.no_grad():
			# Select action according to policy and add clipped noise
			noise = (
				torch.randn_like(action) * self.policy_noise
			).clamp(-self.noise_clip, self.noise_clip)
			
			next_action = (
				self.actor_target(next_state) + noise
			).clamp(-self.max_action, self.max_action)

			# Compute the target Q value
			target_Q1, target_Q2 = self.critic_target(next_state, next_action)
			target_Q = torch.min(target_Q1, target_Q2)
			target_Q = reward + not_done * self.discount * target_Q

		# Get current Q estimates
		current_Q1, current_Q2 = self.critic(state, action)

		# Compute critic loss
		critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

		# Optimize the critic
		self.critic.critic_optimizer.zero_grad()
		critic_loss.backward()
		self.critic.critic_optimizer.step()

		# Delayed policy updates
		if self.total_it % self.policy_freq == 0:

			# Compute actor losse
			actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
			
			# Optimize the actor 
			self.actor.actor_optimizer.zero_grad()
			actor_loss.backward()
			self.actor.actor_optimizer.step()

			# Update the frozen target models
			for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

			for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
# Out:
# True
# 11.8
# cuda

# %%
import gymnasium as gym
import numpy as np
import torch
import os
from torch.utils.tensorboard import SummaryWriter

if __name__ == "__main__":
    # Define environment name
    env_name = "HumanoidStandup-v5"
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Default values
    seed = 0
    start_timesteps = int(10e3)
    eval_freq = int(5e3)
    max_timesteps = int(1e6)
    expl_noise = 0.1
    batch_size = 256
    discount = 0.99
    tau = 0.005
    policy_noise = 0.2
    noise_clip = 0.5
    policy_freq = 2
    save_model = False

    # Initialize environment
    env = gym.make(env_name)
    env.reset(seed=seed)  # Set the seed during environment reset
    env.action_space.seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)

    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]
    max_action = float(env.action_space.high[0])

    if not os.path.exists("./runs"):
        os.makedirs("./runs")
    
    # Initialize TensorBoard writer
    writer = SummaryWriter(f"runs/{env_name}_TD3")
    # Initialize TD3 policy
    policy = TD3_Agent(state_dim=state_dim,action_dim=action_dim,max_action=max_action,hidden_layer_dim1 = 400,hidden_layer_dim2 = 300,
		learning_rate = 1e-3,
        discount=discount,
        tau=tau,
        policy_noise=policy_noise * max_action,
        noise_clip=noise_clip * max_action,
        policy_freq=policy_freq
    )

    avg_rewards = []

    # Initialize variables for training
    state, done,trunc = env.reset()[0], False,False  # Adjust reset output for gymnasium
    episode_reward = 0
    episode_timesteps = 0
    episode_num = 0
    replay_buffer = ReplayBuffer(state_dim, action_dim)

    # Training loop
    for t in range(max_timesteps):
        episode_timesteps += 1

        # Select action
        if t < start_timesteps:
            action = env.action_space.sample()
        else:
            action = (
                policy.select_action(np.array(state))
                + np.random.normal(0, max_action * expl_noise, size=action_dim)
            ).clip(-max_action, max_action)

        # Perform action
        next_state, reward, done, trunc, _ = env.step(action)
        #print(next_state)
        done_bool = float(done or trunc) if episode_timesteps < env.spec.max_episode_steps else 0

        # Store data in replay buffer
        replay_buffer.add(state, action, next_state, reward, done_bool)

        state = next_state
        episode_reward += reward

        # Train policy
        if t >= start_timesteps:
            #torch.cuda.synchronize()
            policy.train(replay_buffer, batch_size)
            #torch.cuda.synchronize()
        
        writer.add_scalar("Reward/Timestep", episode_reward, t)
        # print("Allocated:",torch.cuda.memory_allocated())
        # print("Reserved",torch.cuda.memory_reserved())
        
        if done or trunc:
            print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
            avg_rewards.append(episode_reward)
            state, done, trunc = env.reset()[0], False, False  # Adjust reset output for gymnasium
            episode_reward = 0
            episode_timesteps = 0
            episode_num += 1

            if episode_num %5 == 0:
                writer.add_scalar("Reward/Episode", sum(avg_rewards)/len(avg_rewards), t)
                avg_rewards = []
    writer.close()
# Out:
# Total T: 1000 Episode Num: 1 Episode T: 1000 Reward: 32647.174
# Total T: 2000 Episode Num: 2 Episode T: 1000 Reward: 30947.641
# Total T: 3000 Episode Num: 3 Episode T: 1000 Reward: 33592.958
# Total T: 4000 Episode Num: 4 Episode T: 1000 Reward: 33440.756
# Total T: 5000 Episode Num: 5 Episode T: 1000 Reward: 32164.892
# Total T: 6000 Episode Num: 6 Episode T: 1000 Reward: 30659.192
# Total T: 7000 Episode Num: 7 Episode T: 1000 Reward: 32128.532
# Total T: 8000 Episode Num: 8 Episode T: 1000 Reward: 37270.897
# Total T: 9000 Episode Num: 9 Episode T: 1000 Reward: 32652.963
# Total T: 10000 Episode Num: 10 Episode T: 1000 Reward: 32275.133
# Total T: 11000 Episode Num: 11 Episode T: 1000 Reward: 70304.228
# Total T: 12000 Episode Num: 12 Episode T: 1000 Reward: 66152.244
# Total T: 13000 Episode Num: 13 Episode T: 1000 Reward: 63352.792
# Total T: 14000 Episode Num: 14 Episode T: 1000 Reward: 49723.965
# Total T: 15000 Episode Num: 15 Episode T: 1000 Reward: 51157.640
# Total T: 16000 Episode Num: 16 Episode T: 1000 Reward: 56365.275
# Total T: 17000 Episode Num: 17 Episode T: 1000 Reward: 69081.064
# Total T: 18000 Episode Num: 18 Episode T: 1000 Reward: 77489.638
# Total T: 19000 Episode Num: 19 Episode T: 1000 Reward: 52735.857
# Total T: 20000 Episode Num: 20 Episode T: 1000 Reward: 77812.540
# Total T: 21000 Episode Num: 21 Episode T: 1000 Reward: 49223.523
# Total T: 22000 Episode Num: 22 Episode T: 1000 Reward: 59408.121
# Total T: 23000 Episode Num: 23 Episode T: 1000 Reward: 50569.913
# Total T: 24000 Episode Num: 24 Episode T: 1000 Reward: 55874.620
# Total T: 25000 Episode Num: 25 Episode T: 1000 Reward: 51123.621
# Total T: 26000 Episode Num: 26 Episode T: 1000 Reward: 57845.153
# Total T: 27000 Episode Num: 27 Episode T: 1000 Reward: 73912.992
# Total T: 28000 Episode Num: 28 Episode T: 1000 Reward: 49632.699
# Total T: 29000 Episode Num: 29 Episode T: 1000 Reward: 54027.840
# Total T: 30000 Episode Num: 30 Episode T: 1000 Reward: 55733.958
# Total T: 31000 Episode Num: 31 Episode T: 1000 Reward: 76304.012
# Total T: 32000 Episode Num: 32 Episode T: 1000 Reward: 52153.748
# Total T: 33000 Episode Num: 33 Episode T: 1000 Reward: 75746.405
# Total T: 34000 Episode Num: 34 Episode T: 1000 Reward: 66788.948
# Total T: 35000 Episode Num: 35 Episode T: 1000 Reward: 49593.765
# Total T: 36000 Episode Num: 36 Episode T: 1000 Reward: 55881.978
# Total T: 37000 Episode Num: 37 Episode T: 1000 Reward: 65435.822
# Total T: 38000 Episode Num: 38 Episode T: 1000 Reward: 54514.146
# Total T: 39000 Episode Num: 39 Episode T: 1000 Reward: 49778.358
# Total T: 40000 Episode Num: 40 Episode T: 1000 Reward: 52970.920
# Total T: 41000 Episode Num: 41 Episode T: 1000 Reward: 58028.251
# Total T: 42000 Episode Num: 42 Episode T: 1000 Reward: 61094.514
# Total T: 43000 Episode Num: 43 Episode T: 1000 Reward: 49848.280
# Total T: 44000 Episode Num: 44 Episode T: 1000 Reward: 58945.283
# Total T: 45000 Episode Num: 45 Episode T: 1000 Reward: 50285.368
# Total T: 46000 Episode Num: 46 Episode T: 1000 Reward: 49656.070
# Total T: 47000 Episode Num: 47 Episode T: 1000 Reward: 84488.535
# Total T: 48000 Episode Num: 48 Episode T: 1000 Reward: 60331.469
# Total T: 49000 Episode Num: 49 Episode T: 1000 Reward: 51630.335
# Total T: 50000 Episode Num: 50 Episode T: 1000 Reward: 52634.547
# Total T: 51000 Episode Num: 51 Episode T: 1000 Reward: 60317.301
# Total T: 52000 Episode Num: 52 Episode T: 1000 Reward: 50246.237
# Total T: 53000 Episode Num: 53 Episode T: 1000 Reward: 50436.486
# Total T: 54000 Episode Num: 54 Episode T: 1000 Reward: 79738.317
# Total T: 55000 Episode Num: 55 Episode T: 1000 Reward: 58317.706
# Total T: 56000 Episode Num: 56 Episode T: 1000 Reward: 58924.814
# Total T: 57000 Episode Num: 57 Episode T: 1000 Reward: 64536.413
# Total T: 58000 Episode Num: 58 Episode T: 1000 Reward: 49591.542
# Total T: 59000 Episode Num: 59 Episode T: 1000 Reward: 75453.954
# Total T: 60000 Episode Num: 60 Episode T: 1000 Reward: 49413.358
# Total T: 61000 Episode Num: 61 Episode T: 1000 Reward: 81937.833
# Total T: 62000 Episode Num: 62 Episode T: 1000 Reward: 75421.345
# Total T: 63000 Episode Num: 63 Episode T: 1000 Reward: 67530.905
# Total T: 64000 Episode Num: 64 Episode T: 1000 Reward: 50030.010
# Total T: 65000 Episode Num: 65 Episode T: 1000 Reward: 57766.851
# Total T: 66000 Episode Num: 66 Episode T: 1000 Reward: 82472.366
# Total T: 67000 Episode Num: 67 Episode T: 1000 Reward: 50402.280
# Total T: 68000 Episode Num: 68 Episode T: 1000 Reward: 61306.206
# Total T: 69000 Episode Num: 69 Episode T: 1000 Reward: 80229.527
# Total T: 70000 Episode Num: 70 Episode T: 1000 Reward: 78720.914
# Total T: 71000 Episode Num: 71 Episode T: 1000 Reward: 51374.518
# Total T: 72000 Episode Num: 72 Episode T: 1000 Reward: 56800.235
# Total T: 73000 Episode Num: 73 Episode T: 1000 Reward: 49702.805
# Total T: 74000 Episode Num: 74 Episode T: 1000 Reward: 49416.835
# Total T: 75000 Episode Num: 75 Episode T: 1000 Reward: 49387.766
# Total T: 76000 Episode Num: 76 Episode T: 1000 Reward: 56890.172
# Total T: 77000 Episode Num: 77 Episode T: 1000 Reward: 51067.869
# Total T: 78000 Episode Num: 78 Episode T: 1000 Reward: 53522.362
# Total T: 79000 Episode Num: 79 Episode T: 1000 Reward: 54193.867
# Total T: 80000 Episode Num: 80 Episode T: 1000 Reward: 68105.705
# Total T: 81000 Episode Num: 81 Episode T: 1000 Reward: 50159.855
# Total T: 82000 Episode Num: 82 Episode T: 1000 Reward: 52013.154
# Total T: 83000 Episode Num: 83 Episode T: 1000 Reward: 76081.483
# Total T: 84000 Episode Num: 84 Episode T: 1000 Reward: 65906.936
# Total T: 85000 Episode Num: 85 Episode T: 1000 Reward: 57028.542
# Total T: 86000 Episode Num: 86 Episode T: 1000 Reward: 53086.935
# Total T: 87000 Episode Num: 87 Episode T: 1000 Reward: 51019.307
# Total T: 88000 Episode Num: 88 Episode T: 1000 Reward: 51934.128
# Total T: 89000 Episode Num: 89 Episode T: 1000 Reward: 56769.165
# Total T: 90000 Episode Num: 90 Episode T: 1000 Reward: 62457.502
# Total T: 91000 Episode Num: 91 Episode T: 1000 Reward: 54298.657
# Total T: 92000 Episode Num: 92 Episode T: 1000 Reward: 60858.208
# Total T: 93000 Episode Num: 93 Episode T: 1000 Reward: 60634.506
# Total T: 94000 Episode Num: 94 Episode T: 1000 Reward: 77032.774
# Total T: 95000 Episode Num: 95 Episode T: 1000 Reward: 63060.770
# Total T: 96000 Episode Num: 96 Episode T: 1000 Reward: 61594.407
# Total T: 97000 Episode Num: 97 Episode T: 1000 Reward: 50574.760
# Total T: 98000 Episode Num: 98 Episode T: 1000 Reward: 75908.336
# Total T: 99000 Episode Num: 99 Episode T: 1000 Reward: 57848.685
# Total T: 100000 Episode Num: 100 Episode T: 1000 Reward: 57627.657
# Total T: 101000 Episode Num: 101 Episode T: 1000 Reward: 49526.618
# Total T: 102000 Episode Num: 102 Episode T: 1000 Reward: 54334.797
# Total T: 103000 Episode Num: 103 Episode T: 1000 Reward: 54503.033
# Total T: 104000 Episode Num: 104 Episode T: 1000 Reward: 49767.633
# Total T: 105000 Episode Num: 105 Episode T: 1000 Reward: 49587.202
# Total T: 106000 Episode Num: 106 Episode T: 1000 Reward: 52168.639
# Total T: 107000 Episode Num: 107 Episode T: 1000 Reward: 55369.589
# Total T: 108000 Episode Num: 108 Episode T: 1000 Reward: 65640.667
# Total T: 109000 Episode Num: 109 Episode T: 1000 Reward: 52844.244
# Total T: 110000 Episode Num: 110 Episode T: 1000 Reward: 63045.533
# Total T: 111000 Episode Num: 111 Episode T: 1000 Reward: 57653.123
# Total T: 112000 Episode Num: 112 Episode T: 1000 Reward: 57810.069
# Total T: 113000 Episode Num: 113 Episode T: 1000 Reward: 52331.196
# Total T: 114000 Episode Num: 114 Episode T: 1000 Reward: 59402.365
# Total T: 115000 Episode Num: 115 Episode T: 1000 Reward: 56632.796
# Total T: 116000 Episode Num: 116 Episode T: 1000 Reward: 50503.819
# Total T: 117000 Episode Num: 117 Episode T: 1000 Reward: 67689.253
# Total T: 118000 Episode Num: 118 Episode T: 1000 Reward: 49728.668
# Total T: 119000 Episode Num: 119 Episode T: 1000 Reward: 49796.548
# Total T: 120000 Episode Num: 120 Episode T: 1000 Reward: 80379.208
# Total T: 121000 Episode Num: 121 Episode T: 1000 Reward: 81396.825
# Total T: 122000 Episode Num: 122 Episode T: 1000 Reward: 49368.498
# Total T: 123000 Episode Num: 123 Episode T: 1000 Reward: 49355.627
# Total T: 124000 Episode Num: 124 Episode T: 1000 Reward: 60633.001
# Total T: 125000 Episode Num: 125 Episode T: 1000 Reward: 79849.628
# Total T: 126000 Episode Num: 126 Episode T: 1000 Reward: 52890.090
# Total T: 127000 Episode Num: 127 Episode T: 1000 Reward: 51265.361
# Total T: 128000 Episode Num: 128 Episode T: 1000 Reward: 77360.283
# Total T: 129000 Episode Num: 129 Episode T: 1000 Reward: 54082.840
# Total T: 130000 Episode Num: 130 Episode T: 1000 Reward: 59338.002
# Total T: 131000 Episode Num: 131 Episode T: 1000 Reward: 49187.218
# Total T: 132000 Episode Num: 132 Episode T: 1000 Reward: 61677.444
# Total T: 133000 Episode Num: 133 Episode T: 1000 Reward: 49837.708
# Total T: 134000 Episode Num: 134 Episode T: 1000 Reward: 50798.342
# Total T: 135000 Episode Num: 135 Episode T: 1000 Reward: 56463.020
# Total T: 136000 Episode Num: 136 Episode T: 1000 Reward: 58410.830
# Total T: 137000 Episode Num: 137 Episode T: 1000 Reward: 64578.838
# Total T: 138000 Episode Num: 138 Episode T: 1000 Reward: 50483.757
# Total T: 139000 Episode Num: 139 Episode T: 1000 Reward: 62757.663
# Total T: 140000 Episode Num: 140 Episode T: 1000 Reward: 49544.080
# Total T: 141000 Episode Num: 141 Episode T: 1000 Reward: 58535.833
# Total T: 142000 Episode Num: 142 Episode T: 1000 Reward: 56720.802
# Total T: 143000 Episode Num: 143 Episode T: 1000 Reward: 50668.919
# Total T: 144000 Episode Num: 144 Episode T: 1000 Reward: 49903.912
# Total T: 145000 Episode Num: 145 Episode T: 1000 Reward: 51366.006
# Total T: 146000 Episode Num: 146 Episode T: 1000 Reward: 50534.903
# Total T: 147000 Episode Num: 147 Episode T: 1000 Reward: 49351.109
# Total T: 148000 Episode Num: 148 Episode T: 1000 Reward: 64975.645
# Total T: 149000 Episode Num: 149 Episode T: 1000 Reward: 52967.980
# Total T: 150000 Episode Num: 150 Episode T: 1000 Reward: 54885.847
# Total T: 151000 Episode Num: 151 Episode T: 1000 Reward: 50021.646
# Total T: 152000 Episode Num: 152 Episode T: 1000 Reward: 56401.494
# Total T: 153000 Episode Num: 153 Episode T: 1000 Reward: 52130.547
# Total T: 154000 Episode Num: 154 Episode T: 1000 Reward: 50528.537
# Total T: 155000 Episode Num: 155 Episode T: 1000 Reward: 63962.129
# Total T: 156000 Episode Num: 156 Episode T: 1000 Reward: 49658.046
# Total T: 157000 Episode Num: 157 Episode T: 1000 Reward: 63471.445
# Total T: 158000 Episode Num: 158 Episode T: 1000 Reward: 54063.522
# Total T: 159000 Episode Num: 159 Episode T: 1000 Reward: 68370.545
# Total T: 160000 Episode Num: 160 Episode T: 1000 Reward: 65175.395
# Total T: 161000 Episode Num: 161 Episode T: 1000 Reward: 51634.601
# Total T: 162000 Episode Num: 162 Episode T: 1000 Reward: 63466.402
# Total T: 163000 Episode Num: 163 Episode T: 1000 Reward: 51334.005
# Total T: 164000 Episode Num: 164 Episode T: 1000 Reward: 50277.706
# Total T: 165000 Episode Num: 165 Episode T: 1000 Reward: 63686.755
# Total T: 166000 Episode Num: 166 Episode T: 1000 Reward: 67167.779
# Total T: 167000 Episode Num: 167 Episode T: 1000 Reward: 64279.045
# Total T: 168000 Episode Num: 168 Episode T: 1000 Reward: 57613.096
# Total T: 169000 Episode Num: 169 Episode T: 1000 Reward: 56720.050
# Total T: 170000 Episode Num: 170 Episode T: 1000 Reward: 56791.420
# Total T: 171000 Episode Num: 171 Episode T: 1000 Reward: 49664.520
# Total T: 172000 Episode Num: 172 Episode T: 1000 Reward: 79186.773
# Total T: 173000 Episode Num: 173 Episode T: 1000 Reward: 70031.421
# Total T: 174000 Episode Num: 174 Episode T: 1000 Reward: 50843.208
# Total T: 175000 Episode Num: 175 Episode T: 1000 Reward: 57573.627
# Total T: 176000 Episode Num: 176 Episode T: 1000 Reward: 52948.716
# Total T: 177000 Episode Num: 177 Episode T: 1000 Reward: 50740.773
# Total T: 178000 Episode Num: 178 Episode T: 1000 Reward: 60542.459
# Total T: 179000 Episode Num: 179 Episode T: 1000 Reward: 50037.173
# Total T: 180000 Episode Num: 180 Episode T: 1000 Reward: 58786.931
# Total T: 181000 Episode Num: 181 Episode T: 1000 Reward: 62883.555
# Total T: 182000 Episode Num: 182 Episode T: 1000 Reward: 50686.725
# Total T: 183000 Episode Num: 183 Episode T: 1000 Reward: 53945.495
# Total T: 184000 Episode Num: 184 Episode T: 1000 Reward: 56097.522
# Total T: 185000 Episode Num: 185 Episode T: 1000 Reward: 56558.271
# Total T: 186000 Episode Num: 186 Episode T: 1000 Reward: 57343.979
# Total T: 187000 Episode Num: 187 Episode T: 1000 Reward: 52377.794
# Total T: 188000 Episode Num: 188 Episode T: 1000 Reward: 50938.535
# Total T: 189000 Episode Num: 189 Episode T: 1000 Reward: 54820.655
# Total T: 190000 Episode Num: 190 Episode T: 1000 Reward: 58557.223
# Total T: 191000 Episode Num: 191 Episode T: 1000 Reward: 49919.526
# Total T: 192000 Episode Num: 192 Episode T: 1000 Reward: 57077.030
# Total T: 193000 Episode Num: 193 Episode T: 1000 Reward: 53795.017
# Total T: 194000 Episode Num: 194 Episode T: 1000 Reward: 49876.910
# Total T: 195000 Episode Num: 195 Episode T: 1000 Reward: 57501.866
# Total T: 196000 Episode Num: 196 Episode T: 1000 Reward: 82826.702
# Total T: 197000 Episode Num: 197 Episode T: 1000 Reward: 50150.414
# Total T: 198000 Episode Num: 198 Episode T: 1000 Reward: 86490.455
# Total T: 199000 Episode Num: 199 Episode T: 1000 Reward: 65662.341
# Total T: 200000 Episode Num: 200 Episode T: 1000 Reward: 58061.459
# Total T: 201000 Episode Num: 201 Episode T: 1000 Reward: 58996.692
# Total T: 202000 Episode Num: 202 Episode T: 1000 Reward: 56025.850
# Total T: 203000 Episode Num: 203 Episode T: 1000 Reward: 53552.367
# Total T: 204000 Episode Num: 204 Episode T: 1000 Reward: 50114.752
# Total T: 205000 Episode Num: 205 Episode T: 1000 Reward: 55889.199
# Total T: 206000 Episode Num: 206 Episode T: 1000 Reward: 49874.909
# Total T: 207000 Episode Num: 207 Episode T: 1000 Reward: 49677.758
# Total T: 208000 Episode Num: 208 Episode T: 1000 Reward: 82723.152
# Total T: 209000 Episode Num: 209 Episode T: 1000 Reward: 50072.201
# Total T: 210000 Episode Num: 210 Episode T: 1000 Reward: 62264.487
# Total T: 211000 Episode Num: 211 Episode T: 1000 Reward: 58154.549
# Total T: 212000 Episode Num: 212 Episode T: 1000 Reward: 50067.040
# Total T: 213000 Episode Num: 213 Episode T: 1000 Reward: 51566.843
# Total T: 214000 Episode Num: 214 Episode T: 1000 Reward: 59847.601
# Total T: 215000 Episode Num: 215 Episode T: 1000 Reward: 63289.732
# Total T: 216000 Episode Num: 216 Episode T: 1000 Reward: 76105.773
# Total T: 217000 Episode Num: 217 Episode T: 1000 Reward: 50187.564
# Total T: 218000 Episode Num: 218 Episode T: 1000 Reward: 49904.144
# Total T: 219000 Episode Num: 219 Episode T: 1000 Reward: 59693.339
# Total T: 220000 Episode Num: 220 Episode T: 1000 Reward: 64164.021
# Total T: 221000 Episode Num: 221 Episode T: 1000 Reward: 49504.397
# Total T: 222000 Episode Num: 222 Episode T: 1000 Reward: 82754.632
# Total T: 223000 Episode Num: 223 Episode T: 1000 Reward: 74928.813
# Total T: 224000 Episode Num: 224 Episode T: 1000 Reward: 50652.145
# Total T: 225000 Episode Num: 225 Episode T: 1000 Reward: 52352.327
# Total T: 226000 Episode Num: 226 Episode T: 1000 Reward: 49990.310
# Total T: 227000 Episode Num: 227 Episode T: 1000 Reward: 55179.650
# Total T: 228000 Episode Num: 228 Episode T: 1000 Reward: 53140.539
# Total T: 229000 Episode Num: 229 Episode T: 1000 Reward: 59975.917
# Total T: 230000 Episode Num: 230 Episode T: 1000 Reward: 81906.164
# Total T: 231000 Episode Num: 231 Episode T: 1000 Reward: 57551.847
# Total T: 232000 Episode Num: 232 Episode T: 1000 Reward: 57413.327
# Total T: 233000 Episode Num: 233 Episode T: 1000 Reward: 50053.590
# Total T: 234000 Episode Num: 234 Episode T: 1000 Reward: 50176.925
# Total T: 235000 Episode Num: 235 Episode T: 1000 Reward: 57158.824
# Total T: 236000 Episode Num: 236 Episode T: 1000 Reward: 77045.162
# Total T: 237000 Episode Num: 237 Episode T: 1000 Reward: 58027.324
# Total T: 238000 Episode Num: 238 Episode T: 1000 Reward: 58334.698
# Total T: 239000 Episode Num: 239 Episode T: 1000 Reward: 50267.288
# Total T: 240000 Episode Num: 240 Episode T: 1000 Reward: 50894.644
# Total T: 241000 Episode Num: 241 Episode T: 1000 Reward: 60610.127
# Total T: 242000 Episode Num: 242 Episode T: 1000 Reward: 78187.773
# Total T: 243000 Episode Num: 243 Episode T: 1000 Reward: 58167.977
# Total T: 244000 Episode Num: 244 Episode T: 1000 Reward: 51639.490
# Total T: 245000 Episode Num: 245 Episode T: 1000 Reward: 65463.765
# Total T: 246000 Episode Num: 246 Episode T: 1000 Reward: 54592.418
# Total T: 247000 Episode Num: 247 Episode T: 1000 Reward: 58364.294
# Total T: 248000 Episode Num: 248 Episode T: 1000 Reward: 55979.931
# Total T: 249000 Episode Num: 249 Episode T: 1000 Reward: 62426.000
# Total T: 250000 Episode Num: 250 Episode T: 1000 Reward: 82542.175
# Total T: 251000 Episode Num: 251 Episode T: 1000 Reward: 49550.525
# Total T: 252000 Episode Num: 252 Episode T: 1000 Reward: 54432.013
# Total T: 253000 Episode Num: 253 Episode T: 1000 Reward: 66669.737
# Total T: 254000 Episode Num: 254 Episode T: 1000 Reward: 62775.205
# Total T: 255000 Episode Num: 255 Episode T: 1000 Reward: 60285.639
# Total T: 256000 Episode Num: 256 Episode T: 1000 Reward: 75980.424
# Total T: 257000 Episode Num: 257 Episode T: 1000 Reward: 51641.765
# Total T: 258000 Episode Num: 258 Episode T: 1000 Reward: 60063.449
# Total T: 259000 Episode Num: 259 Episode T: 1000 Reward: 59420.465
# Total T: 260000 Episode Num: 260 Episode T: 1000 Reward: 50771.077
# Total T: 261000 Episode Num: 261 Episode T: 1000 Reward: 49833.488
# Total T: 262000 Episode Num: 262 Episode T: 1000 Reward: 82682.980
# Total T: 263000 Episode Num: 263 Episode T: 1000 Reward: 81594.995
# Total T: 264000 Episode Num: 264 Episode T: 1000 Reward: 51241.517
# Total T: 265000 Episode Num: 265 Episode T: 1000 Reward: 49758.434
# Total T: 266000 Episode Num: 266 Episode T: 1000 Reward: 59297.428
# Total T: 267000 Episode Num: 267 Episode T: 1000 Reward: 69367.722
# Total T: 268000 Episode Num: 268 Episode T: 1000 Reward: 56215.539
# Total T: 269000 Episode Num: 269 Episode T: 1000 Reward: 58755.432
# Total T: 270000 Episode Num: 270 Episode T: 1000 Reward: 55395.156
# Total T: 271000 Episode Num: 271 Episode T: 1000 Reward: 49628.937
# Total T: 272000 Episode Num: 272 Episode T: 1000 Reward: 75541.055
# Total T: 273000 Episode Num: 273 Episode T: 1000 Reward: 49739.429
# Total T: 274000 Episode Num: 274 Episode T: 1000 Reward: 53028.100
# Total T: 275000 Episode Num: 275 Episode T: 1000 Reward: 56141.745
# Total T: 276000 Episode Num: 276 Episode T: 1000 Reward: 66278.229
# Total T: 277000 Episode Num: 277 Episode T: 1000 Reward: 50956.174
# Total T: 278000 Episode Num: 278 Episode T: 1000 Reward: 49581.508
# Total T: 279000 Episode Num: 279 Episode T: 1000 Reward: 50642.057
# Total T: 280000 Episode Num: 280 Episode T: 1000 Reward: 52114.532
# Total T: 281000 Episode Num: 281 Episode T: 1000 Reward: 49455.394
# Total T: 282000 Episode Num: 282 Episode T: 1000 Reward: 79411.657
# Total T: 283000 Episode Num: 283 Episode T: 1000 Reward: 59279.452
# Total T: 284000 Episode Num: 284 Episode T: 1000 Reward: 54435.974
# Total T: 285000 Episode Num: 285 Episode T: 1000 Reward: 50498.969
# Total T: 286000 Episode Num: 286 Episode T: 1000 Reward: 50441.538
# Total T: 287000 Episode Num: 287 Episode T: 1000 Reward: 50792.449
# Total T: 288000 Episode Num: 288 Episode T: 1000 Reward: 76122.111
# Total T: 289000 Episode Num: 289 Episode T: 1000 Reward: 50069.098
# Total T: 290000 Episode Num: 290 Episode T: 1000 Reward: 86823.916
# Total T: 291000 Episode Num: 291 Episode T: 1000 Reward: 61876.612
# Total T: 292000 Episode Num: 292 Episode T: 1000 Reward: 64742.533
# Total T: 293000 Episode Num: 293 Episode T: 1000 Reward: 53562.704
# Total T: 294000 Episode Num: 294 Episode T: 1000 Reward: 58784.807
# Total T: 295000 Episode Num: 295 Episode T: 1000 Reward: 58192.972
# Total T: 296000 Episode Num: 296 Episode T: 1000 Reward: 58819.480
# Total T: 297000 Episode Num: 297 Episode T: 1000 Reward: 50241.827
# Total T: 298000 Episode Num: 298 Episode T: 1000 Reward: 55236.351
# Total T: 299000 Episode Num: 299 Episode T: 1000 Reward: 49722.306
# Total T: 300000 Episode Num: 300 Episode T: 1000 Reward: 49415.655
# Total T: 301000 Episode Num: 301 Episode T: 1000 Reward: 65895.785
# Total T: 302000 Episode Num: 302 Episode T: 1000 Reward: 57701.761
# Total T: 303000 Episode Num: 303 Episode T: 1000 Reward: 53011.029
# Total T: 304000 Episode Num: 304 Episode T: 1000 Reward: 57617.475
# Total T: 305000 Episode Num: 305 Episode T: 1000 Reward: 49893.826
# Total T: 306000 Episode Num: 306 Episode T: 1000 Reward: 49942.978
# Total T: 307000 Episode Num: 307 Episode T: 1000 Reward: 50128.281
# Total T: 308000 Episode Num: 308 Episode T: 1000 Reward: 56935.391
# Total T: 309000 Episode Num: 309 Episode T: 1000 Reward: 49608.173
# Total T: 310000 Episode Num: 310 Episode T: 1000 Reward: 49875.503
# Total T: 311000 Episode Num: 311 Episode T: 1000 Reward: 51387.030
# Total T: 312000 Episode Num: 312 Episode T: 1000 Reward: 50296.725
# Total T: 313000 Episode Num: 313 Episode T: 1000 Reward: 50070.466
# Total T: 314000 Episode Num: 314 Episode T: 1000 Reward: 81816.538
# Total T: 315000 Episode Num: 315 Episode T: 1000 Reward: 50029.975
# Total T: 316000 Episode Num: 316 Episode T: 1000 Reward: 57066.541
# Total T: 317000 Episode Num: 317 Episode T: 1000 Reward: 50127.660
# Total T: 318000 Episode Num: 318 Episode T: 1000 Reward: 51199.744
# Total T: 319000 Episode Num: 319 Episode T: 1000 Reward: 56150.863
# Total T: 320000 Episode Num: 320 Episode T: 1000 Reward: 52110.105
# Total T: 321000 Episode Num: 321 Episode T: 1000 Reward: 54201.431
# Total T: 322000 Episode Num: 322 Episode T: 1000 Reward: 80727.514
# Total T: 323000 Episode Num: 323 Episode T: 1000 Reward: 50490.512
# Total T: 324000 Episode Num: 324 Episode T: 1000 Reward: 59748.563
# Total T: 325000 Episode Num: 325 Episode T: 1000 Reward: 59068.380
# Total T: 326000 Episode Num: 326 Episode T: 1000 Reward: 49646.053
# Total T: 327000 Episode Num: 327 Episode T: 1000 Reward: 49398.592
# Total T: 328000 Episode Num: 328 Episode T: 1000 Reward: 62900.711
# Total T: 329000 Episode Num: 329 Episode T: 1000 Reward: 54405.573
# Total T: 330000 Episode Num: 330 Episode T: 1000 Reward: 53035.425
# Total T: 331000 Episode Num: 331 Episode T: 1000 Reward: 64127.430
# Total T: 332000 Episode Num: 332 Episode T: 1000 Reward: 66573.759
# Total T: 333000 Episode Num: 333 Episode T: 1000 Reward: 53813.575
# Total T: 334000 Episode Num: 334 Episode T: 1000 Reward: 49638.771
# Total T: 335000 Episode Num: 335 Episode T: 1000 Reward: 60742.058
# Total T: 336000 Episode Num: 336 Episode T: 1000 Reward: 54660.635
# Total T: 337000 Episode Num: 337 Episode T: 1000 Reward: 62336.714
# Total T: 338000 Episode Num: 338 Episode T: 1000 Reward: 60242.879
# Total T: 339000 Episode Num: 339 Episode T: 1000 Reward: 81067.524
# Total T: 340000 Episode Num: 340 Episode T: 1000 Reward: 64511.337
# Total T: 341000 Episode Num: 341 Episode T: 1000 Reward: 65138.900
# Total T: 342000 Episode Num: 342 Episode T: 1000 Reward: 56990.222
# Total T: 343000 Episode Num: 343 Episode T: 1000 Reward: 52328.480
# Total T: 344000 Episode Num: 344 Episode T: 1000 Reward: 53546.265
# Total T: 345000 Episode Num: 345 Episode T: 1000 Reward: 53239.507
# Total T: 346000 Episode Num: 346 Episode T: 1000 Reward: 62987.188
# Total T: 347000 Episode Num: 347 Episode T: 1000 Reward: 52253.960
# Total T: 348000 Episode Num: 348 Episode T: 1000 Reward: 76642.779
# Total T: 349000 Episode Num: 349 Episode T: 1000 Reward: 77736.912
# Total T: 350000 Episode Num: 350 Episode T: 1000 Reward: 51386.468
# Total T: 351000 Episode Num: 351 Episode T: 1000 Reward: 54366.492
# Total T: 352000 Episode Num: 352 Episode T: 1000 Reward: 81829.951
# Total T: 353000 Episode Num: 353 Episode T: 1000 Reward: 79408.451
# Total T: 354000 Episode Num: 354 Episode T: 1000 Reward: 57024.961
# Total T: 355000 Episode Num: 355 Episode T: 1000 Reward: 79347.376
# Total T: 356000 Episode Num: 356 Episode T: 1000 Reward: 55162.286
# Total T: 357000 Episode Num: 357 Episode T: 1000 Reward: 61820.504
# Total T: 358000 Episode Num: 358 Episode T: 1000 Reward: 58550.519
# Total T: 359000 Episode Num: 359 Episode T: 1000 Reward: 59477.396
# Total T: 360000 Episode Num: 360 Episode T: 1000 Reward: 50454.742
# Total T: 361000 Episode Num: 361 Episode T: 1000 Reward: 67754.056
# Total T: 362000 Episode Num: 362 Episode T: 1000 Reward: 52549.679
# Total T: 363000 Episode Num: 363 Episode T: 1000 Reward: 70342.367
# Total T: 364000 Episode Num: 364 Episode T: 1000 Reward: 52527.769
# Total T: 365000 Episode Num: 365 Episode T: 1000 Reward: 64904.153
# Total T: 366000 Episode Num: 366 Episode T: 1000 Reward: 57611.453
# Total T: 367000 Episode Num: 367 Episode T: 1000 Reward: 50544.704
# Total T: 368000 Episode Num: 368 Episode T: 1000 Reward: 54911.641
# Total T: 369000 Episode Num: 369 Episode T: 1000 Reward: 82068.146
# Total T: 370000 Episode Num: 370 Episode T: 1000 Reward: 64599.768
# Total T: 371000 Episode Num: 371 Episode T: 1000 Reward: 56135.510
# Total T: 372000 Episode Num: 372 Episode T: 1000 Reward: 62451.719
# Total T: 373000 Episode Num: 373 Episode T: 1000 Reward: 54533.426
# Total T: 374000 Episode Num: 374 Episode T: 1000 Reward: 60763.313
# Total T: 375000 Episode Num: 375 Episode T: 1000 Reward: 75045.938
# Total T: 376000 Episode Num: 376 Episode T: 1000 Reward: 53121.740
# Total T: 377000 Episode Num: 377 Episode T: 1000 Reward: 81807.412
# Total T: 378000 Episode Num: 378 Episode T: 1000 Reward: 58720.880
# Total T: 379000 Episode Num: 379 Episode T: 1000 Reward: 49968.994
# Total T: 380000 Episode Num: 380 Episode T: 1000 Reward: 57247.893
# Total T: 381000 Episode Num: 381 Episode T: 1000 Reward: 55682.967
# Total T: 382000 Episode Num: 382 Episode T: 1000 Reward: 56142.996
# Total T: 383000 Episode Num: 383 Episode T: 1000 Reward: 74555.032
# Total T: 384000 Episode Num: 384 Episode T: 1000 Reward: 49801.824
# Total T: 385000 Episode Num: 385 Episode T: 1000 Reward: 49997.683
# Total T: 386000 Episode Num: 386 Episode T: 1000 Reward: 50390.802
# Total T: 387000 Episode Num: 387 Episode T: 1000 Reward: 66307.436
# Total T: 388000 Episode Num: 388 Episode T: 1000 Reward: 65960.639
# Total T: 389000 Episode Num: 389 Episode T: 1000 Reward: 74665.083
# Total T: 390000 Episode Num: 390 Episode T: 1000 Reward: 49397.395
# Total T: 391000 Episode Num: 391 Episode T: 1000 Reward: 52275.439
# Total T: 392000 Episode Num: 392 Episode T: 1000 Reward: 55302.490
# Total T: 393000 Episode Num: 393 Episode T: 1000 Reward: 62768.294
# Total T: 394000 Episode Num: 394 Episode T: 1000 Reward: 50444.945
# Total T: 395000 Episode Num: 395 Episode T: 1000 Reward: 63518.166
# Total T: 396000 Episode Num: 396 Episode T: 1000 Reward: 58620.630
# Total T: 397000 Episode Num: 397 Episode T: 1000 Reward: 69176.326
# Total T: 398000 Episode Num: 398 Episode T: 1000 Reward: 54892.640
# Total T: 399000 Episode Num: 399 Episode T: 1000 Reward: 59226.884
# Total T: 400000 Episode Num: 400 Episode T: 1000 Reward: 55116.326
# Total T: 401000 Episode Num: 401 Episode T: 1000 Reward: 49387.464
# Total T: 402000 Episode Num: 402 Episode T: 1000 Reward: 56497.083
# Total T: 403000 Episode Num: 403 Episode T: 1000 Reward: 78952.619
# Total T: 404000 Episode Num: 404 Episode T: 1000 Reward: 50445.216
# Total T: 405000 Episode Num: 405 Episode T: 1000 Reward: 67124.053
# Total T: 406000 Episode Num: 406 Episode T: 1000 Reward: 49319.441
# Total T: 407000 Episode Num: 407 Episode T: 1000 Reward: 86141.676
# Total T: 408000 Episode Num: 408 Episode T: 1000 Reward: 54235.419
# Total T: 409000 Episode Num: 409 Episode T: 1000 Reward: 49769.454
# Total T: 410000 Episode Num: 410 Episode T: 1000 Reward: 51622.985
# Total T: 411000 Episode Num: 411 Episode T: 1000 Reward: 56562.948
# Total T: 412000 Episode Num: 412 Episode T: 1000 Reward: 52139.535
# Total T: 413000 Episode Num: 413 Episode T: 1000 Reward: 61710.854
# Total T: 414000 Episode Num: 414 Episode T: 1000 Reward: 50593.559
# Total T: 415000 Episode Num: 415 Episode T: 1000 Reward: 63246.584
# Total T: 416000 Episode Num: 416 Episode T: 1000 Reward: 50036.551
# Total T: 417000 Episode Num: 417 Episode T: 1000 Reward: 63289.637
# Total T: 418000 Episode Num: 418 Episode T: 1000 Reward: 55795.129
# Total T: 419000 Episode Num: 419 Episode T: 1000 Reward: 58198.014
# Total T: 420000 Episode Num: 420 Episode T: 1000 Reward: 50567.480
# Total T: 421000 Episode Num: 421 Episode T: 1000 Reward: 64777.711
# Total T: 422000 Episode Num: 422 Episode T: 1000 Reward: 50149.145
# Total T: 423000 Episode Num: 423 Episode T: 1000 Reward: 58924.755
# Total T: 424000 Episode Num: 424 Episode T: 1000 Reward: 63274.655
# Total T: 425000 Episode Num: 425 Episode T: 1000 Reward: 52191.287
# Total T: 426000 Episode Num: 426 Episode T: 1000 Reward: 63912.913
# Total T: 427000 Episode Num: 427 Episode T: 1000 Reward: 81450.019
# Total T: 428000 Episode Num: 428 Episode T: 1000 Reward: 63246.900
# Total T: 429000 Episode Num: 429 Episode T: 1000 Reward: 66717.785
# Total T: 430000 Episode Num: 430 Episode T: 1000 Reward: 60543.430
# Total T: 431000 Episode Num: 431 Episode T: 1000 Reward: 80208.860
# Total T: 432000 Episode Num: 432 Episode T: 1000 Reward: 83324.499
# Total T: 433000 Episode Num: 433 Episode T: 1000 Reward: 49768.798
# Total T: 434000 Episode Num: 434 Episode T: 1000 Reward: 49219.324
# Total T: 435000 Episode Num: 435 Episode T: 1000 Reward: 82886.634
# Total T: 436000 Episode Num: 436 Episode T: 1000 Reward: 57163.761
# Total T: 437000 Episode Num: 437 Episode T: 1000 Reward: 49996.689
# Total T: 438000 Episode Num: 438 Episode T: 1000 Reward: 63270.703
# Total T: 439000 Episode Num: 439 Episode T: 1000 Reward: 59749.418
# Total T: 440000 Episode Num: 440 Episode T: 1000 Reward: 49314.001
# Total T: 441000 Episode Num: 441 Episode T: 1000 Reward: 55416.859
# Total T: 442000 Episode Num: 442 Episode T: 1000 Reward: 49500.025
# Total T: 443000 Episode Num: 443 Episode T: 1000 Reward: 51649.434
# Total T: 444000 Episode Num: 444 Episode T: 1000 Reward: 54492.191
# Total T: 445000 Episode Num: 445 Episode T: 1000 Reward: 57587.206
# Total T: 446000 Episode Num: 446 Episode T: 1000 Reward: 59463.573
# Total T: 447000 Episode Num: 447 Episode T: 1000 Reward: 50508.121
# Total T: 448000 Episode Num: 448 Episode T: 1000 Reward: 55049.298
# Total T: 449000 Episode Num: 449 Episode T: 1000 Reward: 49598.994
# Total T: 450000 Episode Num: 450 Episode T: 1000 Reward: 49693.552
# Total T: 451000 Episode Num: 451 Episode T: 1000 Reward: 61831.257
# Total T: 452000 Episode Num: 452 Episode T: 1000 Reward: 56036.767
# Total T: 453000 Episode Num: 453 Episode T: 1000 Reward: 79426.818
# Total T: 454000 Episode Num: 454 Episode T: 1000 Reward: 52859.214
# Total T: 455000 Episode Num: 455 Episode T: 1000 Reward: 65118.144
# Total T: 456000 Episode Num: 456 Episode T: 1000 Reward: 56838.459
# Total T: 457000 Episode Num: 457 Episode T: 1000 Reward: 55960.998
# Total T: 458000 Episode Num: 458 Episode T: 1000 Reward: 64040.703
# Total T: 459000 Episode Num: 459 Episode T: 1000 Reward: 62926.132
# Total T: 460000 Episode Num: 460 Episode T: 1000 Reward: 67798.945
# Total T: 461000 Episode Num: 461 Episode T: 1000 Reward: 81523.695
# Total T: 462000 Episode Num: 462 Episode T: 1000 Reward: 50218.337
# Total T: 463000 Episode Num: 463 Episode T: 1000 Reward: 82637.409
# Total T: 464000 Episode Num: 464 Episode T: 1000 Reward: 49824.129
# Total T: 465000 Episode Num: 465 Episode T: 1000 Reward: 59074.507
# Total T: 466000 Episode Num: 466 Episode T: 1000 Reward: 57238.994
# Total T: 467000 Episode Num: 467 Episode T: 1000 Reward: 77782.759
# Total T: 468000 Episode Num: 468 Episode T: 1000 Reward: 63895.155
# Total T: 469000 Episode Num: 469 Episode T: 1000 Reward: 50364.716
# Total T: 470000 Episode Num: 470 Episode T: 1000 Reward: 54171.879
# Total T: 471000 Episode Num: 471 Episode T: 1000 Reward: 78639.051
# Total T: 472000 Episode Num: 472 Episode T: 1000 Reward: 63920.078
# Total T: 473000 Episode Num: 473 Episode T: 1000 Reward: 82196.193
# Total T: 474000 Episode Num: 474 Episode T: 1000 Reward: 54739.356
# Total T: 475000 Episode Num: 475 Episode T: 1000 Reward: 57878.323
# Total T: 476000 Episode Num: 476 Episode T: 1000 Reward: 49596.640
# Total T: 477000 Episode Num: 477 Episode T: 1000 Reward: 57501.952
# Total T: 478000 Episode Num: 478 Episode T: 1000 Reward: 49702.820
# Total T: 479000 Episode Num: 479 Episode T: 1000 Reward: 55911.305
# Total T: 480000 Episode Num: 480 Episode T: 1000 Reward: 50060.081
# Total T: 481000 Episode Num: 481 Episode T: 1000 Reward: 49455.274
# Total T: 482000 Episode Num: 482 Episode T: 1000 Reward: 51544.232
# Total T: 483000 Episode Num: 483 Episode T: 1000 Reward: 62789.520
# Total T: 484000 Episode Num: 484 Episode T: 1000 Reward: 50463.880
# Total T: 485000 Episode Num: 485 Episode T: 1000 Reward: 49745.803
# Total T: 486000 Episode Num: 486 Episode T: 1000 Reward: 62812.682
# Total T: 487000 Episode Num: 487 Episode T: 1000 Reward: 57268.948
# Total T: 488000 Episode Num: 488 Episode T: 1000 Reward: 78761.901
# Total T: 489000 Episode Num: 489 Episode T: 1000 Reward: 49412.997
# Total T: 490000 Episode Num: 490 Episode T: 1000 Reward: 50846.308
# Total T: 491000 Episode Num: 491 Episode T: 1000 Reward: 53390.448
# Total T: 492000 Episode Num: 492 Episode T: 1000 Reward: 52890.595
# Total T: 493000 Episode Num: 493 Episode T: 1000 Reward: 55555.506
# Total T: 494000 Episode Num: 494 Episode T: 1000 Reward: 56918.076
# Total T: 495000 Episode Num: 495 Episode T: 1000 Reward: 55887.023
# Total T: 496000 Episode Num: 496 Episode T: 1000 Reward: 62425.769
# Total T: 497000 Episode Num: 497 Episode T: 1000 Reward: 53577.617
# Total T: 498000 Episode Num: 498 Episode T: 1000 Reward: 50583.443
# Total T: 499000 Episode Num: 499 Episode T: 1000 Reward: 49335.264
# Total T: 500000 Episode Num: 500 Episode T: 1000 Reward: 50329.413
# Total T: 501000 Episode Num: 501 Episode T: 1000 Reward: 50617.370
# Total T: 502000 Episode Num: 502 Episode T: 1000 Reward: 61783.664
# Total T: 503000 Episode Num: 503 Episode T: 1000 Reward: 56843.386
# Total T: 504000 Episode Num: 504 Episode T: 1000 Reward: 64127.189
# Total T: 505000 Episode Num: 505 Episode T: 1000 Reward: 49685.081
# Total T: 506000 Episode Num: 506 Episode T: 1000 Reward: 62122.205
# Total T: 507000 Episode Num: 507 Episode T: 1000 Reward: 50196.378
# Total T: 508000 Episode Num: 508 Episode T: 1000 Reward: 61574.005
# Total T: 509000 Episode Num: 509 Episode T: 1000 Reward: 61264.893
# Total T: 510000 Episode Num: 510 Episode T: 1000 Reward: 49441.681
# Total T: 511000 Episode Num: 511 Episode T: 1000 Reward: 63619.953
# Total T: 512000 Episode Num: 512 Episode T: 1000 Reward: 59858.980
# Total T: 513000 Episode Num: 513 Episode T: 1000 Reward: 52886.631
# Total T: 514000 Episode Num: 514 Episode T: 1000 Reward: 80403.112
# Total T: 515000 Episode Num: 515 Episode T: 1000 Reward: 58338.077
# Total T: 516000 Episode Num: 516 Episode T: 1000 Reward: 49315.799
# Total T: 517000 Episode Num: 517 Episode T: 1000 Reward: 62534.940
# Total T: 518000 Episode Num: 518 Episode T: 1000 Reward: 75055.582
# Total T: 519000 Episode Num: 519 Episode T: 1000 Reward: 54456.682
# Total T: 520000 Episode Num: 520 Episode T: 1000 Reward: 50189.621
# Total T: 521000 Episode Num: 521 Episode T: 1000 Reward: 56367.411
# Total T: 522000 Episode Num: 522 Episode T: 1000 Reward: 72379.403
# Total T: 523000 Episode Num: 523 Episode T: 1000 Reward: 78545.655
# Total T: 524000 Episode Num: 524 Episode T: 1000 Reward: 79591.799
# Total T: 525000 Episode Num: 525 Episode T: 1000 Reward: 78234.894
# Total T: 526000 Episode Num: 526 Episode T: 1000 Reward: 64687.714
# Total T: 527000 Episode Num: 527 Episode T: 1000 Reward: 62304.747
# Total T: 528000 Episode Num: 528 Episode T: 1000 Reward: 51323.570
# Total T: 529000 Episode Num: 529 Episode T: 1000 Reward: 57456.171
# Total T: 530000 Episode Num: 530 Episode T: 1000 Reward: 51666.023
# Total T: 531000 Episode Num: 531 Episode T: 1000 Reward: 51439.654
# Total T: 532000 Episode Num: 532 Episode T: 1000 Reward: 50598.025
# Total T: 533000 Episode Num: 533 Episode T: 1000 Reward: 66713.711
# Total T: 534000 Episode Num: 534 Episode T: 1000 Reward: 49638.637
# Total T: 535000 Episode Num: 535 Episode T: 1000 Reward: 64534.729
# Total T: 536000 Episode Num: 536 Episode T: 1000 Reward: 64611.576
# Total T: 537000 Episode Num: 537 Episode T: 1000 Reward: 62545.106
# Total T: 538000 Episode Num: 538 Episode T: 1000 Reward: 51251.011
# Total T: 539000 Episode Num: 539 Episode T: 1000 Reward: 62352.893
# Total T: 540000 Episode Num: 540 Episode T: 1000 Reward: 61715.334
# Total T: 541000 Episode Num: 541 Episode T: 1000 Reward: 50500.740
# Total T: 542000 Episode Num: 542 Episode T: 1000 Reward: 61015.409
# Total T: 543000 Episode Num: 543 Episode T: 1000 Reward: 49534.308
# Total T: 544000 Episode Num: 544 Episode T: 1000 Reward: 62204.026
# Total T: 545000 Episode Num: 545 Episode T: 1000 Reward: 57670.759
# Total T: 546000 Episode Num: 546 Episode T: 1000 Reward: 56156.997
# Total T: 547000 Episode Num: 547 Episode T: 1000 Reward: 53208.403
# Total T: 548000 Episode Num: 548 Episode T: 1000 Reward: 54935.466
# Total T: 549000 Episode Num: 549 Episode T: 1000 Reward: 56623.025
# Total T: 550000 Episode Num: 550 Episode T: 1000 Reward: 51051.490
# Total T: 551000 Episode Num: 551 Episode T: 1000 Reward: 63918.093
# Total T: 552000 Episode Num: 552 Episode T: 1000 Reward: 66813.716
# Total T: 553000 Episode Num: 553 Episode T: 1000 Reward: 53746.871
# Total T: 554000 Episode Num: 554 Episode T: 1000 Reward: 60004.827
# Total T: 555000 Episode Num: 555 Episode T: 1000 Reward: 55735.093
# Total T: 556000 Episode Num: 556 Episode T: 1000 Reward: 50550.069
# Total T: 557000 Episode Num: 557 Episode T: 1000 Reward: 74081.304
# Total T: 558000 Episode Num: 558 Episode T: 1000 Reward: 59656.145
# Total T: 559000 Episode Num: 559 Episode T: 1000 Reward: 65800.434
# Total T: 560000 Episode Num: 560 Episode T: 1000 Reward: 56343.262
# Total T: 561000 Episode Num: 561 Episode T: 1000 Reward: 59110.960
# Total T: 562000 Episode Num: 562 Episode T: 1000 Reward: 64661.373
# Total T: 563000 Episode Num: 563 Episode T: 1000 Reward: 55527.684
# Total T: 564000 Episode Num: 564 Episode T: 1000 Reward: 57119.707
# Total T: 565000 Episode Num: 565 Episode T: 1000 Reward: 81023.065
# Total T: 566000 Episode Num: 566 Episode T: 1000 Reward: 63239.898
# Total T: 567000 Episode Num: 567 Episode T: 1000 Reward: 50096.125
# Total T: 568000 Episode Num: 568 Episode T: 1000 Reward: 56494.397
# Total T: 569000 Episode Num: 569 Episode T: 1000 Reward: 50213.837
# Total T: 570000 Episode Num: 570 Episode T: 1000 Reward: 55254.709
# Total T: 571000 Episode Num: 571 Episode T: 1000 Reward: 49809.377
# Total T: 572000 Episode Num: 572 Episode T: 1000 Reward: 52627.753
# Total T: 573000 Episode Num: 573 Episode T: 1000 Reward: 63548.498
# Total T: 574000 Episode Num: 574 Episode T: 1000 Reward: 56540.681
# Total T: 575000 Episode Num: 575 Episode T: 1000 Reward: 58397.207
# Total T: 576000 Episode Num: 576 Episode T: 1000 Reward: 62429.816
# Total T: 577000 Episode Num: 577 Episode T: 1000 Reward: 56687.830
# Total T: 578000 Episode Num: 578 Episode T: 1000 Reward: 63929.467
# Total T: 579000 Episode Num: 579 Episode T: 1000 Reward: 49544.340
# Total T: 580000 Episode Num: 580 Episode T: 1000 Reward: 63159.948
# Total T: 581000 Episode Num: 581 Episode T: 1000 Reward: 64766.401
# Total T: 582000 Episode Num: 582 Episode T: 1000 Reward: 60109.145
# Total T: 583000 Episode Num: 583 Episode T: 1000 Reward: 50230.573
# Total T: 584000 Episode Num: 584 Episode T: 1000 Reward: 78029.208
# Total T: 585000 Episode Num: 585 Episode T: 1000 Reward: 65187.239
# Total T: 586000 Episode Num: 586 Episode T: 1000 Reward: 57411.388
# Total T: 587000 Episode Num: 587 Episode T: 1000 Reward: 51606.652
# Total T: 588000 Episode Num: 588 Episode T: 1000 Reward: 56956.918
# Total T: 589000 Episode Num: 589 Episode T: 1000 Reward: 49571.446
# Total T: 590000 Episode Num: 590 Episode T: 1000 Reward: 65489.175
# Total T: 591000 Episode Num: 591 Episode T: 1000 Reward: 49897.317
# Total T: 592000 Episode Num: 592 Episode T: 1000 Reward: 77611.422
# Total T: 593000 Episode Num: 593 Episode T: 1000 Reward: 49614.659
# Total T: 594000 Episode Num: 594 Episode T: 1000 Reward: 50800.061
# Total T: 595000 Episode Num: 595 Episode T: 1000 Reward: 49978.414
# Total T: 596000 Episode Num: 596 Episode T: 1000 Reward: 56372.531
# Total T: 597000 Episode Num: 597 Episode T: 1000 Reward: 50068.262
# Total T: 598000 Episode Num: 598 Episode T: 1000 Reward: 55863.678
# Total T: 599000 Episode Num: 599 Episode T: 1000 Reward: 54635.011
# Total T: 600000 Episode Num: 600 Episode T: 1000 Reward: 50037.527
# Total T: 601000 Episode Num: 601 Episode T: 1000 Reward: 76197.630
# Total T: 602000 Episode Num: 602 Episode T: 1000 Reward: 49549.997
# Total T: 603000 Episode Num: 603 Episode T: 1000 Reward: 56450.422
# Total T: 604000 Episode Num: 604 Episode T: 1000 Reward: 58355.023
# Total T: 605000 Episode Num: 605 Episode T: 1000 Reward: 65249.127
# Total T: 606000 Episode Num: 606 Episode T: 1000 Reward: 59761.513
# Total T: 607000 Episode Num: 607 Episode T: 1000 Reward: 51853.720
# Total T: 608000 Episode Num: 608 Episode T: 1000 Reward: 50841.036
# Total T: 609000 Episode Num: 609 Episode T: 1000 Reward: 49526.263
# Total T: 610000 Episode Num: 610 Episode T: 1000 Reward: 52312.711
# Total T: 611000 Episode Num: 611 Episode T: 1000 Reward: 49949.843
# Total T: 612000 Episode Num: 612 Episode T: 1000 Reward: 84579.725
# Total T: 613000 Episode Num: 613 Episode T: 1000 Reward: 49516.309
# Total T: 614000 Episode Num: 614 Episode T: 1000 Reward: 50121.213
# Total T: 615000 Episode Num: 615 Episode T: 1000 Reward: 53441.640
# Total T: 616000 Episode Num: 616 Episode T: 1000 Reward: 50722.134
# Total T: 617000 Episode Num: 617 Episode T: 1000 Reward: 55537.093
# Total T: 618000 Episode Num: 618 Episode T: 1000 Reward: 78196.915
# Total T: 619000 Episode Num: 619 Episode T: 1000 Reward: 78470.781
# Total T: 620000 Episode Num: 620 Episode T: 1000 Reward: 54410.325
# Total T: 621000 Episode Num: 621 Episode T: 1000 Reward: 52408.737
# Total T: 622000 Episode Num: 622 Episode T: 1000 Reward: 50457.641
# Total T: 623000 Episode Num: 623 Episode T: 1000 Reward: 59463.276
# Total T: 624000 Episode Num: 624 Episode T: 1000 Reward: 49684.806
# Total T: 625000 Episode Num: 625 Episode T: 1000 Reward: 54889.418
# Total T: 626000 Episode Num: 626 Episode T: 1000 Reward: 74676.448
# Total T: 627000 Episode Num: 627 Episode T: 1000 Reward: 64607.554
# Total T: 628000 Episode Num: 628 Episode T: 1000 Reward: 63483.046
# Total T: 629000 Episode Num: 629 Episode T: 1000 Reward: 49881.057
# Total T: 630000 Episode Num: 630 Episode T: 1000 Reward: 54874.463
# Total T: 631000 Episode Num: 631 Episode T: 1000 Reward: 82397.282
# Total T: 632000 Episode Num: 632 Episode T: 1000 Reward: 63284.774
# Total T: 633000 Episode Num: 633 Episode T: 1000 Reward: 56490.996
# Total T: 634000 Episode Num: 634 Episode T: 1000 Reward: 59077.263
# Total T: 635000 Episode Num: 635 Episode T: 1000 Reward: 56479.877
# Total T: 636000 Episode Num: 636 Episode T: 1000 Reward: 81998.883
# Total T: 637000 Episode Num: 637 Episode T: 1000 Reward: 74595.912
# Total T: 638000 Episode Num: 638 Episode T: 1000 Reward: 80996.082
# Total T: 639000 Episode Num: 639 Episode T: 1000 Reward: 59178.902
# Total T: 640000 Episode Num: 640 Episode T: 1000 Reward: 60814.074
# Total T: 641000 Episode Num: 641 Episode T: 1000 Reward: 49629.524
# Total T: 642000 Episode Num: 642 Episode T: 1000 Reward: 49570.727
# Total T: 643000 Episode Num: 643 Episode T: 1000 Reward: 50365.053
# Total T: 644000 Episode Num: 644 Episode T: 1000 Reward: 49964.672
# Total T: 645000 Episode Num: 645 Episode T: 1000 Reward: 79902.255
# Total T: 646000 Episode Num: 646 Episode T: 1000 Reward: 57914.264
# Total T: 647000 Episode Num: 647 Episode T: 1000 Reward: 54984.334
# Total T: 648000 Episode Num: 648 Episode T: 1000 Reward: 63304.825
# Total T: 649000 Episode Num: 649 Episode T: 1000 Reward: 55023.472
# Total T: 650000 Episode Num: 650 Episode T: 1000 Reward: 61261.520
# Total T: 651000 Episode Num: 651 Episode T: 1000 Reward: 50954.808
# Total T: 652000 Episode Num: 652 Episode T: 1000 Reward: 54853.515
# Total T: 653000 Episode Num: 653 Episode T: 1000 Reward: 50049.575
# Total T: 654000 Episode Num: 654 Episode T: 1000 Reward: 50340.285
# Total T: 655000 Episode Num: 655 Episode T: 1000 Reward: 49662.675
# Total T: 656000 Episode Num: 656 Episode T: 1000 Reward: 50018.258
# Total T: 657000 Episode Num: 657 Episode T: 1000 Reward: 83935.142
# Total T: 658000 Episode Num: 658 Episode T: 1000 Reward: 75806.086
# Total T: 659000 Episode Num: 659 Episode T: 1000 Reward: 79617.482
# Total T: 660000 Episode Num: 660 Episode T: 1000 Reward: 84261.382
# Total T: 661000 Episode Num: 661 Episode T: 1000 Reward: 62067.263
# Total T: 662000 Episode Num: 662 Episode T: 1000 Reward: 50912.896
# Total T: 663000 Episode Num: 663 Episode T: 1000 Reward: 53604.229
# Total T: 664000 Episode Num: 664 Episode T: 1000 Reward: 57716.281
# Total T: 665000 Episode Num: 665 Episode T: 1000 Reward: 60813.634
# Total T: 666000 Episode Num: 666 Episode T: 1000 Reward: 54459.909
# Total T: 667000 Episode Num: 667 Episode T: 1000 Reward: 50559.702
# Total T: 668000 Episode Num: 668 Episode T: 1000 Reward: 49845.985
# Total T: 669000 Episode Num: 669 Episode T: 1000 Reward: 55793.049
# Total T: 670000 Episode Num: 670 Episode T: 1000 Reward: 53170.735
# Total T: 671000 Episode Num: 671 Episode T: 1000 Reward: 63152.043
# Total T: 672000 Episode Num: 672 Episode T: 1000 Reward: 57513.145
# Total T: 673000 Episode Num: 673 Episode T: 1000 Reward: 50839.390
# Total T: 674000 Episode Num: 674 Episode T: 1000 Reward: 61288.851
# Total T: 675000 Episode Num: 675 Episode T: 1000 Reward: 49957.852
# Total T: 676000 Episode Num: 676 Episode T: 1000 Reward: 59532.604
# Total T: 677000 Episode Num: 677 Episode T: 1000 Reward: 63544.788
# Total T: 678000 Episode Num: 678 Episode T: 1000 Reward: 49722.335
# Total T: 679000 Episode Num: 679 Episode T: 1000 Reward: 49708.661
# Total T: 680000 Episode Num: 680 Episode T: 1000 Reward: 77379.492
# Total T: 681000 Episode Num: 681 Episode T: 1000 Reward: 79179.208
# Total T: 682000 Episode Num: 682 Episode T: 1000 Reward: 49482.656
# Total T: 683000 Episode Num: 683 Episode T: 1000 Reward: 62668.658
# Total T: 684000 Episode Num: 684 Episode T: 1000 Reward: 64361.378
# Total T: 685000 Episode Num: 685 Episode T: 1000 Reward: 77808.098
# Total T: 686000 Episode Num: 686 Episode T: 1000 Reward: 64509.989
# Total T: 687000 Episode Num: 687 Episode T: 1000 Reward: 51038.064
# Total T: 688000 Episode Num: 688 Episode T: 1000 Reward: 50108.995
# Total T: 689000 Episode Num: 689 Episode T: 1000 Reward: 51045.928
# Total T: 690000 Episode Num: 690 Episode T: 1000 Reward: 51494.517
# Total T: 691000 Episode Num: 691 Episode T: 1000 Reward: 81757.720
# Total T: 692000 Episode Num: 692 Episode T: 1000 Reward: 55350.073
# Total T: 693000 Episode Num: 693 Episode T: 1000 Reward: 49606.430
# Total T: 694000 Episode Num: 694 Episode T: 1000 Reward: 49224.086
# Total T: 695000 Episode Num: 695 Episode T: 1000 Reward: 52474.356
# Total T: 696000 Episode Num: 696 Episode T: 1000 Reward: 49691.137
# Total T: 697000 Episode Num: 697 Episode T: 1000 Reward: 55806.055
# Total T: 698000 Episode Num: 698 Episode T: 1000 Reward: 52622.007
# Total T: 699000 Episode Num: 699 Episode T: 1000 Reward: 62484.483
# Total T: 700000 Episode Num: 700 Episode T: 1000 Reward: 56412.085
# Total T: 701000 Episode Num: 701 Episode T: 1000 Reward: 50736.875
# Total T: 702000 Episode Num: 702 Episode T: 1000 Reward: 59035.273
# Total T: 703000 Episode Num: 703 Episode T: 1000 Reward: 62724.145
# Total T: 704000 Episode Num: 704 Episode T: 1000 Reward: 50765.701
# Total T: 705000 Episode Num: 705 Episode T: 1000 Reward: 58537.159
# Total T: 706000 Episode Num: 706 Episode T: 1000 Reward: 73396.612
# Total T: 707000 Episode Num: 707 Episode T: 1000 Reward: 77850.740
# Total T: 708000 Episode Num: 708 Episode T: 1000 Reward: 63193.727
# Total T: 709000 Episode Num: 709 Episode T: 1000 Reward: 50261.122
# Total T: 710000 Episode Num: 710 Episode T: 1000 Reward: 50038.889
# Total T: 711000 Episode Num: 711 Episode T: 1000 Reward: 61145.231
# Total T: 712000 Episode Num: 712 Episode T: 1000 Reward: 50136.918
# Total T: 713000 Episode Num: 713 Episode T: 1000 Reward: 52607.707
# Total T: 714000 Episode Num: 714 Episode T: 1000 Reward: 50159.935
# Total T: 715000 Episode Num: 715 Episode T: 1000 Reward: 63029.245
# Total T: 716000 Episode Num: 716 Episode T: 1000 Reward: 49845.477
# Total T: 717000 Episode Num: 717 Episode T: 1000 Reward: 49554.821
# Total T: 718000 Episode Num: 718 Episode T: 1000 Reward: 50625.349
# Total T: 719000 Episode Num: 719 Episode T: 1000 Reward: 49772.069
# Total T: 720000 Episode Num: 720 Episode T: 1000 Reward: 82191.013
# Total T: 721000 Episode Num: 721 Episode T: 1000 Reward: 64825.876
# Total T: 722000 Episode Num: 722 Episode T: 1000 Reward: 63039.247
# Total T: 723000 Episode Num: 723 Episode T: 1000 Reward: 53989.636
# Total T: 724000 Episode Num: 724 Episode T: 1000 Reward: 50079.607
# Total T: 725000 Episode Num: 725 Episode T: 1000 Reward: 59859.612
# Total T: 726000 Episode Num: 726 Episode T: 1000 Reward: 80160.844
# Total T: 727000 Episode Num: 727 Episode T: 1000 Reward: 57771.548
# Total T: 728000 Episode Num: 728 Episode T: 1000 Reward: 63558.155
# Total T: 729000 Episode Num: 729 Episode T: 1000 Reward: 54626.919
# Total T: 730000 Episode Num: 730 Episode T: 1000 Reward: 65079.562
# Total T: 731000 Episode Num: 731 Episode T: 1000 Reward: 53423.653
# Total T: 732000 Episode Num: 732 Episode T: 1000 Reward: 49687.785
# Total T: 733000 Episode Num: 733 Episode T: 1000 Reward: 49843.963
# Total T: 734000 Episode Num: 734 Episode T: 1000 Reward: 60993.533
# Total T: 735000 Episode Num: 735 Episode T: 1000 Reward: 51394.052
# Total T: 736000 Episode Num: 736 Episode T: 1000 Reward: 57433.624
# Total T: 737000 Episode Num: 737 Episode T: 1000 Reward: 55721.001
# Total T: 738000 Episode Num: 738 Episode T: 1000 Reward: 51486.459
# Total T: 739000 Episode Num: 739 Episode T: 1000 Reward: 53288.046
# Total T: 740000 Episode Num: 740 Episode T: 1000 Reward: 64968.371
# Total T: 741000 Episode Num: 741 Episode T: 1000 Reward: 63199.178
# Total T: 742000 Episode Num: 742 Episode T: 1000 Reward: 51110.986
# Total T: 743000 Episode Num: 743 Episode T: 1000 Reward: 74367.083
# Total T: 744000 Episode Num: 744 Episode T: 1000 Reward: 49694.109
# Total T: 745000 Episode Num: 745 Episode T: 1000 Reward: 60268.302
# Total T: 746000 Episode Num: 746 Episode T: 1000 Reward: 53245.188
# Total T: 747000 Episode Num: 747 Episode T: 1000 Reward: 51178.950
# Total T: 748000 Episode Num: 748 Episode T: 1000 Reward: 65132.698
# Total T: 749000 Episode Num: 749 Episode T: 1000 Reward: 50252.631
# Total T: 750000 Episode Num: 750 Episode T: 1000 Reward: 56567.265
# Total T: 751000 Episode Num: 751 Episode T: 1000 Reward: 49949.877
# Total T: 752000 Episode Num: 752 Episode T: 1000 Reward: 53284.149
# Total T: 753000 Episode Num: 753 Episode T: 1000 Reward: 64459.079
# Total T: 754000 Episode Num: 754 Episode T: 1000 Reward: 55648.790
# Total T: 755000 Episode Num: 755 Episode T: 1000 Reward: 58017.683
# Total T: 756000 Episode Num: 756 Episode T: 1000 Reward: 54718.118
# Total T: 757000 Episode Num: 757 Episode T: 1000 Reward: 50704.050
# Total T: 758000 Episode Num: 758 Episode T: 1000 Reward: 54092.098
# Total T: 759000 Episode Num: 759 Episode T: 1000 Reward: 65210.708
# Total T: 760000 Episode Num: 760 Episode T: 1000 Reward: 50923.093
# Total T: 761000 Episode Num: 761 Episode T: 1000 Reward: 53661.750
# Total T: 762000 Episode Num: 762 Episode T: 1000 Reward: 57193.060
# Total T: 763000 Episode Num: 763 Episode T: 1000 Reward: 53843.485

# %%
import gymnasium as gym
from gymnasium.wrappers import RecordVideo
import os

def view_policy_and_save_video(policy, env_name, seed, video_dir="./videos/humanoid", max_steps=1000):
    # Ensure the video directory exists
    os.makedirs(video_dir, exist_ok=True)

    # Create the environment with video recording
    env = gym.make(env_name, render_mode="rgb_array")  # Use "rgb_array" mode for video
    env = RecordVideo(env, video_folder=video_dir, episode_trigger=lambda ep: True)  # Record every episode
    env.reset(seed=seed)  # Set the seed for reproducibility

    state, done = env.reset()[0], False
    total_reward = 0
    step = 0

    while not done and step < max_steps:
        # Select action using the trained policy
        action = policy.select_action(np.array(state))

        # Take the action in the environment
        state, reward, done, _, _ = env.step(action)
        total_reward += reward

        step += 1

    print(f"Total reward: {total_reward:.3f} over {step} steps")
    env.close()

    print(f"Video saved to {video_dir}")

# Call this function after training the policy
view_policy_and_save_video(policy, env_name="Hopper-v5", seed=0)

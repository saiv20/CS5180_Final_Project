# %%
import gymnasium as gym
import torch
import copy
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import os
from torch.utils.tensorboard import SummaryWriter

# %%
class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0
		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))
		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done
		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)
		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)
	

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.is_available())
print(torch.version.cuda)
print(device)

class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 256).to(device)
        self.l2 = nn.Linear(256, 256).to(device)
        self.mean = nn.Linear(256, action_dim).to(device)
        self.log_std = nn.Linear(256, action_dim).to(device)
        self.max_action = max_action

    def forward(self, state):
        x = F.relu(self.l1(state)).to(device)
        x = F.relu(self.l2(x)).to(device)
        mean = self.mean(x)
        log_std = torch.clamp(self.log_std(x), -20, 2).to(device)  
        return mean, log_std

    def sample_action(self, state):
        mean, log_std = self.forward(state)
        std = log_std.exp() 
        normal = torch.distributions.Normal(mean, std)
        action = normal.rsample()  
        log_prob = normal.log_prob(action).sum(dim=-1)  
        action = torch.tanh(action).to(device)
        log_prob -= torch.log(1 - action.pow(2) + 1e-6).sum(dim=-1).to(device)  
        action = action * self.max_action
        return action, log_prob

class Critic(nn.Module):
	def __init__(self, state_dim, action_dim):
		super(Critic, self).__init__()
		self.l1 = nn.Linear(state_dim + action_dim, 256).to(device)
		self.l2 = nn.Linear(256, 256).to(device)
		self.l3 = nn.Linear(256, 1).to(device)
		self.l4 = nn.Linear(state_dim + action_dim, 256).to(device)
		self.l5 = nn.Linear(256, 256).to(device)
		self.l6 = nn.Linear(256, 1).to(device)

	def forward(self, state, action):
		sa = torch.cat([state, action], 1).to(device)
		q1 = F.relu(self.l1(sa)).to(device)
		q1 = F.relu(self.l2(q1)).to(device)
		q1 = self.l3(q1)
		q2 = F.relu(self.l4(sa)).to(device)
		q2 = F.relu(self.l5(q2)).to(device)
		q2 = self.l6(q2)
		return q1, q2


	def Q1(self, state, action):
		sa = torch.cat([state, action], 1).to(device)
		q1 = F.relu(self.l1(sa)).to(device)
		q1 = F.relu(self.l2(q1)).to(device)
		q1 = self.l3(q1)
		return q1


class SAC(object):
    def __init__(
        self,
        state_dim,
        action_dim,
        max_action,
        discount=0.99,
        tau=0.005,
        alpha=0.2,
        target_entropy=None,
        actor_lr=3e-4,
        critic_lr=3e-4,
        alpha_lr=3e-4,
    ):
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=actor_lr)
        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=critic_lr)
        self.log_alpha = torch.tensor(np.log(alpha), requires_grad=True, device=device)
        self.alpha_optimizer = torch.optim.Adam([self.log_alpha], lr=alpha_lr)
        self.target_entropy = target_entropy if target_entropy is not None else -action_dim
        self.max_action = max_action
        self.discount = discount
        self.tau = tau

    @property
    def alpha(self):
        return self.log_alpha.exp()
    def select_action(self, state, deterministic=False):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        if deterministic:
            action, _ = self.actor(state) 
            return action.cpu().data.numpy().flatten()
        else:
            action, _ = self.actor.sample_action(state)
            return action.cpu().data.numpy().flatten()

    def train(self, replay_buffer, batch_size=256):
        
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)
        with torch.no_grad():
            next_action, log_prob = self.actor.sample_action(next_state)
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2) - self.alpha * log_prob
            target_Q = reward + not_done * self.discount * target_Q

        current_Q1, current_Q2 = self.critic(state, action)
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()
        action, log_prob = self.actor.sample_action(state)
        q1, q2 = self.critic(state, action)
        actor_loss = (self.alpha * log_prob - torch.min(q1, q2)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        alpha_loss = -(self.log_alpha * (log_prob + self.target_entropy).detach()).mean()
        self.alpha_optimizer.zero_grad()
        alpha_loss.backward()
        self.alpha_optimizer.step()

        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
# Out:
# True
# 11.8
# cuda

# %%
print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
if __name__ == "__main__":
    
    env_name = "BipedalWalker-v3"
    seed = 0
    start_timesteps = int(10e3)
    eval_freq = int(5e3)
    max_timesteps = int(1e6)
    batch_size = 256
    discount = 0.99
    tau = 0.005
    alpha = 0.2  
    save_model = True
    env = gym.make(env_name)
    env.reset(seed=seed)  
    env.action_space.seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.shape[0]
    max_action = float(env.action_space.high[0])

    if not os.path.exists("./runs"):
        os.makedirs("./runs")
    
    writer = SummaryWriter(f"runs/{env_name}_SAC")

    policy = SAC(
        state_dim=state_dim,
        action_dim=action_dim,
        max_action=max_action,
        discount=discount,
        tau=tau,
        alpha=alpha
    )
    avg_rewards = []

    state, done, trunc = env.reset()[0], False, False  
    episode_reward = 0
    episode_timesteps = 0
    episode_num = 0
    replay_buffer = ReplayBuffer(state_dim, action_dim)

    for t in range(max_timesteps):
        episode_timesteps += 1

        if t < start_timesteps:
            action = env.action_space.sample()
        else:
            action = policy.select_action(np.array(state))  
        next_state, reward, done, trunc, _ = env.step(action)
        done_bool = float(done or trunc) if episode_timesteps < env.spec.max_episode_steps else 0

        replay_buffer.add(state, action, next_state, reward, done_bool)
        state = next_state
        episode_reward += reward

        if t >= start_timesteps:
            policy.train(replay_buffer, batch_size)

        writer.add_scalar("Reward/Timestep", episode_reward, t)    

        if done or trunc:
            print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
            avg_rewards.append(episode_reward)
            state, done, trunc = env.reset()[0], False, False 
            episode_reward = 0
            episode_timesteps = 0
            episode_num += 1

            if episode_num %5 == 0:
                writer.add_scalar("Reward/Episode", sum(avg_rewards)/len(avg_rewards), t)
                avg_rewards = []
    writer.close()
# Out:
# Total T: 59 Episode Num: 1 Episode T: 59 Reward: -108.465
# Total T: 124 Episode Num: 2 Episode T: 65 Reward: -113.457
# Total T: 1724 Episode Num: 3 Episode T: 1600 Reward: -82.656
# Total T: 1837 Episode Num: 4 Episode T: 113 Reward: -106.184
# Total T: 1927 Episode Num: 5 Episode T: 90 Reward: -116.472
# Total T: 3527 Episode Num: 6 Episode T: 1600 Reward: -80.395
# Total T: 3581 Episode Num: 7 Episode T: 54 Reward: -106.627
# Total T: 3696 Episode Num: 8 Episode T: 115 Reward: -99.927
# Total T: 3787 Episode Num: 9 Episode T: 91 Reward: -96.982
# Total T: 3846 Episode Num: 10 Episode T: 59 Reward: -103.279
# Total T: 3894 Episode Num: 11 Episode T: 48 Reward: -110.402
# Total T: 5494 Episode Num: 12 Episode T: 1600 Reward: -73.905
# Total T: 5579 Episode Num: 13 Episode T: 85 Reward: -99.266
# Total T: 5655 Episode Num: 14 Episode T: 76 Reward: -105.410
# Total T: 5705 Episode Num: 15 Episode T: 50 Reward: -111.717
# Total T: 5776 Episode Num: 16 Episode T: 71 Reward: -102.234
# Total T: 7376 Episode Num: 17 Episode T: 1600 Reward: -78.731
# Total T: 7424 Episode Num: 18 Episode T: 48 Reward: -105.002
# Total T: 9024 Episode Num: 19 Episode T: 1600 Reward: -80.444
# Total T: 9095 Episode Num: 20 Episode T: 71 Reward: -101.614
# Total T: 9172 Episode Num: 21 Episode T: 77 Reward: -103.219
# C:\Users\samri\AppData\Local\Temp\ipykernel_21456\3950792500.py:189: UserWarning: Using a target size (torch.Size([256, 256])) that is different to the input size (torch.Size([256, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
# Total T: 10772 Episode Num: 22 Episode T: 1600 Reward: -90.976
# Total T: 11853 Episode Num: 23 Episode T: 1081 Reward: -183.671
# Total T: 11900 Episode Num: 24 Episode T: 47 Reward: -106.839
# Total T: 11950 Episode Num: 25 Episode T: 50 Reward: -106.344
# Total T: 12018 Episode Num: 26 Episode T: 68 Reward: -114.177
# Total T: 12069 Episode Num: 27 Episode T: 51 Reward: -104.321
# Total T: 12123 Episode Num: 28 Episode T: 54 Reward: -108.301
# Total T: 12229 Episode Num: 29 Episode T: 106 Reward: -117.027
# Total T: 12303 Episode Num: 30 Episode T: 74 Reward: -109.014
# Total T: 13903 Episode Num: 31 Episode T: 1600 Reward: -115.134
# Total T: 13973 Episode Num: 32 Episode T: 70 Reward: -103.772
# Total T: 14093 Episode Num: 33 Episode T: 120 Reward: -106.546
# Total T: 14174 Episode Num: 34 Episode T: 81 Reward: -101.685
# Total T: 14270 Episode Num: 35 Episode T: 96 Reward: -102.822
# Total T: 14458 Episode Num: 36 Episode T: 188 Reward: -106.738
# Total T: 14523 Episode Num: 37 Episode T: 65 Reward: -101.924
# Total T: 14601 Episode Num: 38 Episode T: 78 Reward: -104.067
# Total T: 14706 Episode Num: 39 Episode T: 105 Reward: -100.159
# Total T: 14787 Episode Num: 40 Episode T: 81 Reward: -101.868
# Total T: 15207 Episode Num: 41 Episode T: 420 Reward: -110.505
# Total T: 15306 Episode Num: 42 Episode T: 99 Reward: -126.414
# Total T: 15374 Episode Num: 43 Episode T: 68 Reward: -104.602
# Total T: 15442 Episode Num: 44 Episode T: 68 Reward: -101.314
# Total T: 15506 Episode Num: 45 Episode T: 64 Reward: -105.266
# Total T: 15586 Episode Num: 46 Episode T: 80 Reward: -102.367
# Total T: 15647 Episode Num: 47 Episode T: 61 Reward: -100.143
# Total T: 15740 Episode Num: 48 Episode T: 93 Reward: -99.134
# Total T: 15832 Episode Num: 49 Episode T: 92 Reward: -123.476
# Total T: 15899 Episode Num: 50 Episode T: 67 Reward: -104.722
# Total T: 15967 Episode Num: 51 Episode T: 68 Reward: -104.551
# Total T: 16034 Episode Num: 52 Episode T: 67 Reward: -99.423
# Total T: 16156 Episode Num: 53 Episode T: 122 Reward: -103.816
# Total T: 16209 Episode Num: 54 Episode T: 53 Reward: -103.359
# Total T: 16278 Episode Num: 55 Episode T: 69 Reward: -98.619
# Total T: 16339 Episode Num: 56 Episode T: 61 Reward: -101.457
# Total T: 16415 Episode Num: 57 Episode T: 76 Reward: -99.558
# Total T: 16493 Episode Num: 58 Episode T: 78 Reward: -97.497
# Total T: 16571 Episode Num: 59 Episode T: 78 Reward: -120.798
# Total T: 16644 Episode Num: 60 Episode T: 73 Reward: -98.284
# Total T: 16760 Episode Num: 61 Episode T: 116 Reward: -102.860
# Total T: 16833 Episode Num: 62 Episode T: 73 Reward: -98.353
# Total T: 16874 Episode Num: 63 Episode T: 41 Reward: -103.550
# Total T: 16977 Episode Num: 64 Episode T: 103 Reward: -130.770
# Total T: 17055 Episode Num: 65 Episode T: 78 Reward: -97.747
# Total T: 17133 Episode Num: 66 Episode T: 78 Reward: -97.339
# Total T: 17375 Episode Num: 67 Episode T: 242 Reward: -135.998
# Total T: 17444 Episode Num: 68 Episode T: 69 Reward: -96.930
# Total T: 17519 Episode Num: 69 Episode T: 75 Reward: -97.812
# Total T: 17604 Episode Num: 70 Episode T: 85 Reward: -98.893
# Total T: 17678 Episode Num: 71 Episode T: 74 Reward: -104.735
# Total T: 17756 Episode Num: 72 Episode T: 78 Reward: -97.225
# Total T: 17808 Episode Num: 73 Episode T: 52 Reward: -105.449
# Total T: 17904 Episode Num: 74 Episode T: 96 Reward: -97.229
# Total T: 17984 Episode Num: 75 Episode T: 80 Reward: -99.416
# Total T: 18053 Episode Num: 76 Episode T: 69 Reward: -99.491
# Total T: 18141 Episode Num: 77 Episode T: 88 Reward: -95.853
# Total T: 18220 Episode Num: 78 Episode T: 79 Reward: -97.691
# Total T: 18265 Episode Num: 79 Episode T: 45 Reward: -103.157
# Total T: 18392 Episode Num: 80 Episode T: 127 Reward: -97.706
# Total T: 18499 Episode Num: 81 Episode T: 107 Reward: -100.079
# Total T: 18575 Episode Num: 82 Episode T: 76 Reward: -100.777
# Total T: 18630 Episode Num: 83 Episode T: 55 Reward: -102.412
# Total T: 18704 Episode Num: 84 Episode T: 74 Reward: -98.840
# Total T: 18777 Episode Num: 85 Episode T: 73 Reward: -98.339
# Total T: 18862 Episode Num: 86 Episode T: 85 Reward: -101.049
# Total T: 18937 Episode Num: 87 Episode T: 75 Reward: -104.348
# Total T: 19014 Episode Num: 88 Episode T: 77 Reward: -99.315
# Total T: 19109 Episode Num: 89 Episode T: 95 Reward: -103.215
# Total T: 19276 Episode Num: 90 Episode T: 167 Reward: -129.816
# Total T: 19356 Episode Num: 91 Episode T: 80 Reward: -122.363
# Total T: 19431 Episode Num: 92 Episode T: 75 Reward: -104.957
# Total T: 19502 Episode Num: 93 Episode T: 71 Reward: -103.080
# Total T: 19579 Episode Num: 94 Episode T: 77 Reward: -109.113
# Total T: 19689 Episode Num: 95 Episode T: 110 Reward: -100.338
# Total T: 19758 Episode Num: 96 Episode T: 69 Reward: -101.566
# Total T: 19845 Episode Num: 97 Episode T: 87 Reward: -106.506
# Total T: 19913 Episode Num: 98 Episode T: 68 Reward: -103.454
# Total T: 20026 Episode Num: 99 Episode T: 113 Reward: -106.045
# Total T: 20100 Episode Num: 100 Episode T: 74 Reward: -102.722
# Total T: 20226 Episode Num: 101 Episode T: 126 Reward: -106.071
# Total T: 20312 Episode Num: 102 Episode T: 86 Reward: -104.244
# Total T: 20447 Episode Num: 103 Episode T: 135 Reward: -106.860
# Total T: 20547 Episode Num: 104 Episode T: 100 Reward: -109.707
# Total T: 20615 Episode Num: 105 Episode T: 68 Reward: -103.283
# Total T: 20689 Episode Num: 106 Episode T: 74 Reward: -102.503
# Total T: 20840 Episode Num: 107 Episode T: 151 Reward: -107.252
# Total T: 20913 Episode Num: 108 Episode T: 73 Reward: -100.939
# Total T: 22513 Episode Num: 109 Episode T: 1600 Reward: -65.271
# Total T: 22606 Episode Num: 110 Episode T: 93 Reward: -99.917
# Total T: 22689 Episode Num: 111 Episode T: 83 Reward: -102.436
# Total T: 24289 Episode Num: 112 Episode T: 1600 Reward: -87.676
# Total T: 24375 Episode Num: 113 Episode T: 86 Reward: -100.867
# Total T: 25975 Episode Num: 114 Episode T: 1600 Reward: -96.963
# Total T: 27575 Episode Num: 115 Episode T: 1600 Reward: -105.390
# Total T: 29175 Episode Num: 116 Episode T: 1600 Reward: -96.838
# Total T: 29269 Episode Num: 117 Episode T: 94 Reward: -128.196
# Total T: 30869 Episode Num: 118 Episode T: 1600 Reward: -83.858
# Total T: 32469 Episode Num: 119 Episode T: 1600 Reward: -110.051
# Total T: 34069 Episode Num: 120 Episode T: 1600 Reward: -88.762
# Total T: 35669 Episode Num: 121 Episode T: 1600 Reward: -79.657
# Total T: 35727 Episode Num: 122 Episode T: 58 Reward: -114.219
# Total T: 35799 Episode Num: 123 Episode T: 72 Reward: -119.141
# Total T: 37399 Episode Num: 124 Episode T: 1600 Reward: -82.381
# Total T: 38999 Episode Num: 125 Episode T: 1600 Reward: -70.787
# Total T: 40178 Episode Num: 126 Episode T: 1179 Reward: -209.774
# Total T: 41778 Episode Num: 127 Episode T: 1600 Reward: -101.055
# Total T: 41836 Episode Num: 128 Episode T: 58 Reward: -120.087
# Total T: 43436 Episode Num: 129 Episode T: 1600 Reward: -78.353
# Total T: 43551 Episode Num: 130 Episode T: 115 Reward: -107.598
# Total T: 45151 Episode Num: 131 Episode T: 1600 Reward: -66.983
# Total T: 46751 Episode Num: 132 Episode T: 1600 Reward: -105.071
# Total T: 46925 Episode Num: 133 Episode T: 174 Reward: -106.889
# Total T: 46999 Episode Num: 134 Episode T: 74 Reward: -118.215
# Total T: 47070 Episode Num: 135 Episode T: 71 Reward: -115.447
# Total T: 47126 Episode Num: 136 Episode T: 56 Reward: -110.131
# Total T: 48726 Episode Num: 137 Episode T: 1600 Reward: -92.645
# Total T: 50326 Episode Num: 138 Episode T: 1600 Reward: -44.301
# Total T: 51926 Episode Num: 139 Episode T: 1600 Reward: -74.125
# Total T: 53526 Episode Num: 140 Episode T: 1600 Reward: -78.987
# Total T: 55126 Episode Num: 141 Episode T: 1600 Reward: -57.952
# Total T: 55193 Episode Num: 142 Episode T: 67 Reward: -119.238
# Total T: 55280 Episode Num: 143 Episode T: 87 Reward: -124.307
# Total T: 56880 Episode Num: 144 Episode T: 1600 Reward: -51.011
# Total T: 56923 Episode Num: 145 Episode T: 43 Reward: -108.573
# Total T: 58523 Episode Num: 146 Episode T: 1600 Reward: -55.484
# Total T: 58577 Episode Num: 147 Episode T: 54 Reward: -116.113
# Total T: 58647 Episode Num: 148 Episode T: 70 Reward: -119.244
# Total T: 58711 Episode Num: 149 Episode T: 64 Reward: -122.858
# Total T: 58759 Episode Num: 150 Episode T: 48 Reward: -115.921
# Total T: 58821 Episode Num: 151 Episode T: 62 Reward: -118.857
# Total T: 58903 Episode Num: 152 Episode T: 82 Reward: -117.220
# Total T: 58977 Episode Num: 153 Episode T: 74 Reward: -119.295
# Total T: 59048 Episode Num: 154 Episode T: 71 Reward: -116.321
# Total T: 59114 Episode Num: 155 Episode T: 66 Reward: -115.593
# Total T: 59191 Episode Num: 156 Episode T: 77 Reward: -117.450
# Total T: 59266 Episode Num: 157 Episode T: 75 Reward: -116.206
# Total T: 59330 Episode Num: 158 Episode T: 64 Reward: -115.740
# Total T: 60930 Episode Num: 159 Episode T: 1600 Reward: -80.728
# Total T: 61029 Episode Num: 160 Episode T: 99 Reward: -117.180
# Total T: 62629 Episode Num: 161 Episode T: 1600 Reward: -75.055
# Total T: 64229 Episode Num: 162 Episode T: 1600 Reward: -88.310
# Total T: 64326 Episode Num: 163 Episode T: 97 Reward: -96.855
# Total T: 64429 Episode Num: 164 Episode T: 103 Reward: -107.782
# Total T: 64505 Episode Num: 165 Episode T: 76 Reward: -119.414
# Total T: 64587 Episode Num: 166 Episode T: 82 Reward: -96.612
# Total T: 64666 Episode Num: 167 Episode T: 79 Reward: -98.379
# Total T: 64756 Episode Num: 168 Episode T: 90 Reward: -99.555
# Total T: 65030 Episode Num: 169 Episode T: 274 Reward: -92.389
# Total T: 65104 Episode Num: 170 Episode T: 74 Reward: -98.398
# Total T: 65161 Episode Num: 171 Episode T: 57 Reward: -115.338
# Total T: 65347 Episode Num: 172 Episode T: 186 Reward: -98.609
# Total T: 65766 Episode Num: 173 Episode T: 419 Reward: -117.340
# Total T: 65839 Episode Num: 174 Episode T: 73 Reward: -97.977
# Total T: 65937 Episode Num: 175 Episode T: 98 Reward: -97.839
# Total T: 66010 Episode Num: 176 Episode T: 73 Reward: -97.254
# Total T: 66117 Episode Num: 177 Episode T: 107 Reward: -97.174
# Total T: 66167 Episode Num: 178 Episode T: 50 Reward: -114.701
# Total T: 66457 Episode Num: 179 Episode T: 290 Reward: -112.611
# Total T: 68057 Episode Num: 180 Episode T: 1600 Reward: -88.403
# Total T: 68161 Episode Num: 181 Episode T: 104 Reward: -98.923
# Total T: 68242 Episode Num: 182 Episode T: 81 Reward: -97.033
# Total T: 68313 Episode Num: 183 Episode T: 71 Reward: -98.703
# Total T: 69913 Episode Num: 184 Episode T: 1600 Reward: -81.662
# Total T: 69987 Episode Num: 185 Episode T: 74 Reward: -101.310
# Total T: 70069 Episode Num: 186 Episode T: 82 Reward: -102.308
# Total T: 70638 Episode Num: 187 Episode T: 569 Reward: -121.697
# Total T: 70751 Episode Num: 188 Episode T: 113 Reward: -101.966
# Total T: 70832 Episode Num: 189 Episode T: 81 Reward: -101.733
# Total T: 70963 Episode Num: 190 Episode T: 131 Reward: -112.028
# Total T: 71049 Episode Num: 191 Episode T: 86 Reward: -98.242
# Total T: 71142 Episode Num: 192 Episode T: 93 Reward: -112.364
# Total T: 71224 Episode Num: 193 Episode T: 82 Reward: -114.494
# Total T: 71329 Episode Num: 194 Episode T: 105 Reward: -113.075
# Total T: 71426 Episode Num: 195 Episode T: 97 Reward: -114.071
# Total T: 71525 Episode Num: 196 Episode T: 99 Reward: -113.505
# Total T: 71647 Episode Num: 197 Episode T: 122 Reward: -102.746
# Total T: 71951 Episode Num: 198 Episode T: 304 Reward: -102.542
# Total T: 73551 Episode Num: 199 Episode T: 1600 Reward: -64.057
# Total T: 75151 Episode Num: 200 Episode T: 1600 Reward: -58.779
# Total T: 75322 Episode Num: 201 Episode T: 171 Reward: -123.063
# Total T: 76922 Episode Num: 202 Episode T: 1600 Reward: -85.624
# Total T: 78522 Episode Num: 203 Episode T: 1600 Reward: -69.476
# Total T: 80122 Episode Num: 204 Episode T: 1600 Reward: -66.091
# Total T: 81722 Episode Num: 205 Episode T: 1600 Reward: -76.010
# Total T: 83322 Episode Num: 206 Episode T: 1600 Reward: -57.109
# Total T: 84922 Episode Num: 207 Episode T: 1600 Reward: -64.655
# Total T: 84986 Episode Num: 208 Episode T: 64 Reward: -109.537
# Total T: 86586 Episode Num: 209 Episode T: 1600 Reward: -88.224
# Total T: 86737 Episode Num: 210 Episode T: 151 Reward: -102.485
# Total T: 87778 Episode Num: 211 Episode T: 1041 Reward: -103.820
# Total T: 88480 Episode Num: 212 Episode T: 702 Reward: -102.327
# Total T: 90080 Episode Num: 213 Episode T: 1600 Reward: -46.829
# Total T: 91680 Episode Num: 214 Episode T: 1600 Reward: -61.086
# Total T: 91870 Episode Num: 215 Episode T: 190 Reward: -111.520
# Total T: 93470 Episode Num: 216 Episode T: 1600 Reward: -122.963
# Total T: 93658 Episode Num: 217 Episode T: 188 Reward: -99.832
# Total T: 95258 Episode Num: 218 Episode T: 1600 Reward: -48.898
# Total T: 95401 Episode Num: 219 Episode T: 143 Reward: -109.077
# Total T: 95485 Episode Num: 220 Episode T: 84 Reward: -105.896
# Total T: 97085 Episode Num: 221 Episode T: 1600 Reward: -42.506
# Total T: 98685 Episode Num: 222 Episode T: 1600 Reward: -43.396
# Total T: 100285 Episode Num: 223 Episode T: 1600 Reward: -49.921
# Total T: 101885 Episode Num: 224 Episode T: 1600 Reward: -48.792
# Total T: 103485 Episode Num: 225 Episode T: 1600 Reward: -47.288
# Total T: 105085 Episode Num: 226 Episode T: 1600 Reward: -51.944
# Total T: 106685 Episode Num: 227 Episode T: 1600 Reward: -81.344
# Total T: 107634 Episode Num: 228 Episode T: 949 Reward: -129.585
# Total T: 109234 Episode Num: 229 Episode T: 1600 Reward: -31.540
# Total T: 109332 Episode Num: 230 Episode T: 98 Reward: -123.335
# Total T: 110115 Episode Num: 231 Episode T: 783 Reward: -112.540
# Total T: 110211 Episode Num: 232 Episode T: 96 Reward: -103.280
# Total T: 110414 Episode Num: 233 Episode T: 203 Reward: -102.783
# Total T: 110684 Episode Num: 234 Episode T: 270 Reward: -116.374
# Total T: 112284 Episode Num: 235 Episode T: 1600 Reward: -9.553
# Total T: 113274 Episode Num: 236 Episode T: 990 Reward: -134.562
# Total T: 114874 Episode Num: 237 Episode T: 1600 Reward: -36.163
# Total T: 116474 Episode Num: 238 Episode T: 1600 Reward: -44.521
# Total T: 118074 Episode Num: 239 Episode T: 1600 Reward: -43.661
# Total T: 119674 Episode Num: 240 Episode T: 1600 Reward: -23.378
# Total T: 121274 Episode Num: 241 Episode T: 1600 Reward: -28.753
# Total T: 122874 Episode Num: 242 Episode T: 1600 Reward: -35.850
# Total T: 124474 Episode Num: 243 Episode T: 1600 Reward: -31.413
# Total T: 126074 Episode Num: 244 Episode T: 1600 Reward: -1.889
# Total T: 126663 Episode Num: 245 Episode T: 589 Reward: -104.005
# Total T: 126772 Episode Num: 246 Episode T: 109 Reward: -98.066
# Total T: 128372 Episode Num: 247 Episode T: 1600 Reward: -23.881
# Total T: 129972 Episode Num: 248 Episode T: 1600 Reward: -30.847
# Total T: 131572 Episode Num: 249 Episode T: 1600 Reward: -83.997
# Total T: 133172 Episode Num: 250 Episode T: 1600 Reward: -16.438
# Total T: 134744 Episode Num: 251 Episode T: 1572 Reward: -127.314
# Total T: 136344 Episode Num: 252 Episode T: 1600 Reward: 16.844
# Total T: 137944 Episode Num: 253 Episode T: 1600 Reward: -20.415
# Total T: 139544 Episode Num: 254 Episode T: 1600 Reward: -6.849
# Total T: 141144 Episode Num: 255 Episode T: 1600 Reward: 22.365
# Total T: 142744 Episode Num: 256 Episode T: 1600 Reward: 3.357
# Total T: 144344 Episode Num: 257 Episode T: 1600 Reward: -44.030
# Total T: 145944 Episode Num: 258 Episode T: 1600 Reward: -45.037
# Total T: 147544 Episode Num: 259 Episode T: 1600 Reward: -38.649
# Total T: 149144 Episode Num: 260 Episode T: 1600 Reward: -51.753
# Total T: 150744 Episode Num: 261 Episode T: 1600 Reward: -47.610
# Total T: 152344 Episode Num: 262 Episode T: 1600 Reward: -16.625
# Total T: 153944 Episode Num: 263 Episode T: 1600 Reward: 54.834
# Total T: 155544 Episode Num: 264 Episode T: 1600 Reward: 66.885
# Total T: 155949 Episode Num: 265 Episode T: 405 Reward: -85.879
# Total T: 156691 Episode Num: 266 Episode T: 742 Reward: -95.514
# Total T: 158291 Episode Num: 267 Episode T: 1600 Reward: 62.808
# Total T: 159650 Episode Num: 268 Episode T: 1359 Reward: -65.540
# Total T: 160245 Episode Num: 269 Episode T: 595 Reward: -91.368
# Total T: 160430 Episode Num: 270 Episode T: 185 Reward: -100.371
# Total T: 160783 Episode Num: 271 Episode T: 353 Reward: -92.947
# Total T: 161008 Episode Num: 272 Episode T: 225 Reward: -113.836
# Total T: 162608 Episode Num: 273 Episode T: 1600 Reward: -21.350
# Total T: 164208 Episode Num: 274 Episode T: 1600 Reward: -49.047
# Total T: 165808 Episode Num: 275 Episode T: 1600 Reward: -47.399
# Total T: 167408 Episode Num: 276 Episode T: 1600 Reward: -58.246
# Total T: 169008 Episode Num: 277 Episode T: 1600 Reward: -58.870
# Total T: 170608 Episode Num: 278 Episode T: 1600 Reward: -36.025
# Total T: 172208 Episode Num: 279 Episode T: 1600 Reward: -75.462
# Total T: 173808 Episode Num: 280 Episode T: 1600 Reward: -32.677
# Total T: 175408 Episode Num: 281 Episode T: 1600 Reward: -40.701
# Total T: 177008 Episode Num: 282 Episode T: 1600 Reward: -66.727
# Total T: 178608 Episode Num: 283 Episode T: 1600 Reward: -47.115
# Total T: 180208 Episode Num: 284 Episode T: 1600 Reward: -60.850
# Total T: 181808 Episode Num: 285 Episode T: 1600 Reward: -47.467
# Total T: 183408 Episode Num: 286 Episode T: 1600 Reward: -52.749
# Total T: 185008 Episode Num: 287 Episode T: 1600 Reward: -46.085
# Total T: 185274 Episode Num: 288 Episode T: 266 Reward: -102.167
# Total T: 186874 Episode Num: 289 Episode T: 1600 Reward: -20.860
# Total T: 188474 Episode Num: 290 Episode T: 1600 Reward: 126.026
# Total T: 190074 Episode Num: 291 Episode T: 1600 Reward: 134.910
# Total T: 191674 Episode Num: 292 Episode T: 1600 Reward: 127.724
# Total T: 193274 Episode Num: 293 Episode T: 1600 Reward: -38.790
# Total T: 194874 Episode Num: 294 Episode T: 1600 Reward: 30.036
# Total T: 196474 Episode Num: 295 Episode T: 1600 Reward: 150.818
# Total T: 198074 Episode Num: 296 Episode T: 1600 Reward: 117.111
# Total T: 199674 Episode Num: 297 Episode T: 1600 Reward: 4.827
# Total T: 201274 Episode Num: 298 Episode T: 1600 Reward: 123.324
# Total T: 202874 Episode Num: 299 Episode T: 1600 Reward: 95.767
# Total T: 204474 Episode Num: 300 Episode T: 1600 Reward: 131.551
# Total T: 206074 Episode Num: 301 Episode T: 1600 Reward: 178.470
# Total T: 207674 Episode Num: 302 Episode T: 1600 Reward: 154.400
# Total T: 209274 Episode Num: 303 Episode T: 1600 Reward: 183.450
# Total T: 210874 Episode Num: 304 Episode T: 1600 Reward: 152.691
# Total T: 212474 Episode Num: 305 Episode T: 1600 Reward: 147.172
# Total T: 214074 Episode Num: 306 Episode T: 1600 Reward: 189.992
# Total T: 215674 Episode Num: 307 Episode T: 1600 Reward: 192.932
# Total T: 217274 Episode Num: 308 Episode T: 1600 Reward: 221.013
# Total T: 218874 Episode Num: 309 Episode T: 1600 Reward: 229.396
# Total T: 220474 Episode Num: 310 Episode T: 1600 Reward: 224.423
# Total T: 222074 Episode Num: 311 Episode T: 1600 Reward: 236.436
# Total T: 223674 Episode Num: 312 Episode T: 1600 Reward: 233.976
# Total T: 223962 Episode Num: 313 Episode T: 288 Reward: -83.370
# Total T: 225562 Episode Num: 314 Episode T: 1600 Reward: 225.678
# Total T: 227162 Episode Num: 315 Episode T: 1600 Reward: 240.014
# Total T: 228762 Episode Num: 316 Episode T: 1600 Reward: 223.910
# Total T: 230362 Episode Num: 317 Episode T: 1600 Reward: 254.440
# Total T: 231962 Episode Num: 318 Episode T: 1600 Reward: 273.754
# Total T: 233562 Episode Num: 319 Episode T: 1600 Reward: 260.825
# Total T: 235162 Episode Num: 320 Episode T: 1600 Reward: 257.207
# Total T: 236686 Episode Num: 321 Episode T: 1524 Reward: 273.529
# Total T: 238258 Episode Num: 322 Episode T: 1572 Reward: 268.021
# Total T: 239841 Episode Num: 323 Episode T: 1583 Reward: 266.863
# Total T: 241353 Episode Num: 324 Episode T: 1512 Reward: 271.435
# Total T: 242860 Episode Num: 325 Episode T: 1507 Reward: 275.028
# Total T: 244364 Episode Num: 326 Episode T: 1504 Reward: 274.491
# Total T: 245694 Episode Num: 327 Episode T: 1330 Reward: 170.158
# Total T: 247125 Episode Num: 328 Episode T: 1431 Reward: 273.621
# Total T: 248524 Episode Num: 329 Episode T: 1399 Reward: 277.071
# Total T: 250040 Episode Num: 330 Episode T: 1516 Reward: 271.326
# Total T: 251407 Episode Num: 331 Episode T: 1367 Reward: 167.625
# Total T: 252908 Episode Num: 332 Episode T: 1501 Reward: 268.470
# Total T: 254196 Episode Num: 333 Episode T: 1288 Reward: 141.445
# Total T: 254882 Episode Num: 334 Episode T: 686 Reward: 14.988
# Total T: 256276 Episode Num: 335 Episode T: 1394 Reward: 277.023
# Total T: 257658 Episode Num: 336 Episode T: 1382 Reward: 275.942
# Total T: 259148 Episode Num: 337 Episode T: 1490 Reward: 270.577
# Total T: 259739 Episode Num: 338 Episode T: 591 Reward: 17.226
# Total T: 260021 Episode Num: 339 Episode T: 282 Reward: -57.420
# Total T: 261393 Episode Num: 340 Episode T: 1372 Reward: 149.693
# Total T: 262807 Episode Num: 341 Episode T: 1414 Reward: 274.187
# Total T: 264172 Episode Num: 342 Episode T: 1365 Reward: 279.474
# Total T: 265499 Episode Num: 343 Episode T: 1327 Reward: 284.864
# Total T: 266854 Episode Num: 344 Episode T: 1355 Reward: 282.663
# Total T: 268168 Episode Num: 345 Episode T: 1314 Reward: 285.305
# Total T: 269411 Episode Num: 346 Episode T: 1243 Reward: 157.293
# Total T: 270768 Episode Num: 347 Episode T: 1357 Reward: 284.474
# Total T: 272064 Episode Num: 348 Episode T: 1296 Reward: 285.586
# Total T: 273344 Episode Num: 349 Episode T: 1280 Reward: 285.358
# Total T: 274594 Episode Num: 350 Episode T: 1250 Reward: 287.107
# Total T: 275868 Episode Num: 351 Episode T: 1274 Reward: 290.110
# Total T: 277095 Episode Num: 352 Episode T: 1227 Reward: 289.700
# Total T: 278328 Episode Num: 353 Episode T: 1233 Reward: 290.249
# Total T: 279593 Episode Num: 354 Episode T: 1265 Reward: 289.577
# Total T: 280829 Episode Num: 355 Episode T: 1236 Reward: 291.452
# Total T: 282030 Episode Num: 356 Episode T: 1201 Reward: 290.542
# Total T: 283298 Episode Num: 357 Episode T: 1268 Reward: 290.112
# Total T: 284568 Episode Num: 358 Episode T: 1270 Reward: 285.575
# Total T: 285810 Episode Num: 359 Episode T: 1242 Reward: 290.381
# Total T: 287041 Episode Num: 360 Episode T: 1231 Reward: 292.323
# Total T: 288211 Episode Num: 361 Episode T: 1170 Reward: 292.597
# Total T: 289399 Episode Num: 362 Episode T: 1188 Reward: 290.939
# Total T: 290669 Episode Num: 363 Episode T: 1270 Reward: 289.378
# Total T: 291861 Episode Num: 364 Episode T: 1192 Reward: 291.619
# Total T: 293031 Episode Num: 365 Episode T: 1170 Reward: 293.255
# Total T: 294206 Episode Num: 366 Episode T: 1175 Reward: 291.872
# Total T: 295392 Episode Num: 367 Episode T: 1186 Reward: 293.419
# Total T: 296553 Episode Num: 368 Episode T: 1161 Reward: 293.649
# Total T: 297699 Episode Num: 369 Episode T: 1146 Reward: 295.037
# Total T: 298868 Episode Num: 370 Episode T: 1169 Reward: 292.356
# Total T: 300011 Episode Num: 371 Episode T: 1143 Reward: 294.882
# Total T: 301168 Episode Num: 372 Episode T: 1157 Reward: 294.222
# Total T: 302327 Episode Num: 373 Episode T: 1159 Reward: 294.385
# Total T: 303464 Episode Num: 374 Episode T: 1137 Reward: 295.051
# Total T: 304649 Episode Num: 375 Episode T: 1185 Reward: 290.613
# Total T: 305021 Episode Num: 376 Episode T: 372 Reward: -18.970
# Total T: 306222 Episode Num: 377 Episode T: 1201 Reward: 290.190
# Total T: 307368 Episode Num: 378 Episode T: 1146 Reward: 292.968
# Total T: 308447 Episode Num: 379 Episode T: 1079 Reward: 299.723
# Total T: 308502 Episode Num: 380 Episode T: 55 Reward: -103.004
# Total T: 309670 Episode Num: 381 Episode T: 1168 Reward: 292.926
# Total T: 310816 Episode Num: 382 Episode T: 1146 Reward: 293.499
# Total T: 311962 Episode Num: 383 Episode T: 1146 Reward: 295.117
# Total T: 313085 Episode Num: 384 Episode T: 1123 Reward: 295.791
# Total T: 314218 Episode Num: 385 Episode T: 1133 Reward: 295.260
# Total T: 315328 Episode Num: 386 Episode T: 1110 Reward: 295.594
# Total T: 316450 Episode Num: 387 Episode T: 1122 Reward: 295.965
# Total T: 317493 Episode Num: 388 Episode T: 1043 Reward: 300.611
# Total T: 318634 Episode Num: 389 Episode T: 1141 Reward: 294.766
# Total T: 319736 Episode Num: 390 Episode T: 1102 Reward: 296.319
# Total T: 320825 Episode Num: 391 Episode T: 1089 Reward: 296.731
# Total T: 321921 Episode Num: 392 Episode T: 1096 Reward: 296.344
# Total T: 322991 Episode Num: 393 Episode T: 1070 Reward: 295.628
# Total T: 324038 Episode Num: 394 Episode T: 1047 Reward: 300.055
# Total T: 325075 Episode Num: 395 Episode T: 1037 Reward: 300.524
# Total T: 326148 Episode Num: 396 Episode T: 1073 Reward: 298.065
# Total T: 327187 Episode Num: 397 Episode T: 1039 Reward: 297.354
# Total T: 328268 Episode Num: 398 Episode T: 1081 Reward: 296.559
# Total T: 329303 Episode Num: 399 Episode T: 1035 Reward: 300.635
# Total T: 330324 Episode Num: 400 Episode T: 1021 Reward: 300.647
# Total T: 331346 Episode Num: 401 Episode T: 1022 Reward: 300.742
# Total T: 332358 Episode Num: 402 Episode T: 1012 Reward: 300.870
# Total T: 332705 Episode Num: 403 Episode T: 347 Reward: -27.303
# Total T: 333771 Episode Num: 404 Episode T: 1066 Reward: 297.137
# Total T: 334849 Episode Num: 405 Episode T: 1078 Reward: 298.956
# Total T: 335854 Episode Num: 406 Episode T: 1005 Reward: 300.245
# Total T: 336861 Episode Num: 407 Episode T: 1007 Reward: 300.132
# Total T: 337909 Episode Num: 408 Episode T: 1048 Reward: 299.393
# Total T: 338923 Episode Num: 409 Episode T: 1014 Reward: 302.309
# Total T: 339971 Episode Num: 410 Episode T: 1048 Reward: 302.600
# Total T: 341016 Episode Num: 411 Episode T: 1045 Reward: 301.394
# Total T: 342041 Episode Num: 412 Episode T: 1025 Reward: 301.970
# Total T: 343068 Episode Num: 413 Episode T: 1027 Reward: 305.392
# Total T: 344109 Episode Num: 414 Episode T: 1041 Reward: 300.827
# Total T: 345113 Episode Num: 415 Episode T: 1004 Reward: 303.777
# Total T: 346151 Episode Num: 416 Episode T: 1038 Reward: 300.085
# Total T: 347180 Episode Num: 417 Episode T: 1029 Reward: 302.700
# Total T: 348213 Episode Num: 418 Episode T: 1033 Reward: 301.128
# Total T: 349236 Episode Num: 419 Episode T: 1023 Reward: 302.912
# Total T: 350279 Episode Num: 420 Episode T: 1043 Reward: 299.012
# Total T: 351251 Episode Num: 421 Episode T: 972 Reward: 303.350
# Total T: 351908 Episode Num: 422 Episode T: 657 Reward: 90.065
# Total T: 352923 Episode Num: 423 Episode T: 1015 Reward: 299.557
# Total T: 353752 Episode Num: 424 Episode T: 829 Reward: 139.845
# Total T: 354751 Episode Num: 425 Episode T: 999 Reward: 304.182
# Total T: 355737 Episode Num: 426 Episode T: 986 Reward: 303.573
# Total T: 356729 Episode Num: 427 Episode T: 992 Reward: 304.258
# Total T: 357707 Episode Num: 428 Episode T: 978 Reward: 305.128
# Total T: 358676 Episode Num: 429 Episode T: 969 Reward: 305.647
# Total T: 359682 Episode Num: 430 Episode T: 1006 Reward: 305.042
# Total T: 360673 Episode Num: 431 Episode T: 991 Reward: 305.536
# Total T: 361667 Episode Num: 432 Episode T: 994 Reward: 304.363
# Total T: 362638 Episode Num: 433 Episode T: 971 Reward: 304.758
# Total T: 363612 Episode Num: 434 Episode T: 974 Reward: 305.068
# Total T: 364583 Episode Num: 435 Episode T: 971 Reward: 305.525
# Total T: 365558 Episode Num: 436 Episode T: 975 Reward: 304.213
# Total T: 366538 Episode Num: 437 Episode T: 980 Reward: 304.825
# Total T: 367555 Episode Num: 438 Episode T: 1017 Reward: 302.206
# Total T: 368527 Episode Num: 439 Episode T: 972 Reward: 306.808
# Total T: 369502 Episode Num: 440 Episode T: 975 Reward: 308.059
# Total T: 370483 Episode Num: 441 Episode T: 981 Reward: 307.141
# Total T: 371484 Episode Num: 442 Episode T: 1001 Reward: 303.035
# Total T: 372494 Episode Num: 443 Episode T: 1010 Reward: 302.672
# Total T: 373476 Episode Num: 444 Episode T: 982 Reward: 305.255
# Total T: 374476 Episode Num: 445 Episode T: 1000 Reward: 302.249
# Total T: 375474 Episode Num: 446 Episode T: 998 Reward: 303.385
# Total T: 376449 Episode Num: 447 Episode T: 975 Reward: 305.153
# Total T: 377437 Episode Num: 448 Episode T: 988 Reward: 304.365
# Total T: 378381 Episode Num: 449 Episode T: 944 Reward: 308.124
# Total T: 379371 Episode Num: 450 Episode T: 990 Reward: 306.126
# Total T: 380316 Episode Num: 451 Episode T: 945 Reward: 309.173
# Total T: 381260 Episode Num: 452 Episode T: 944 Reward: 308.375
# Total T: 382220 Episode Num: 453 Episode T: 960 Reward: 308.599
# Total T: 383182 Episode Num: 454 Episode T: 962 Reward: 307.392
# Total T: 384212 Episode Num: 455 Episode T: 1030 Reward: 302.663
# Total T: 385176 Episode Num: 456 Episode T: 964 Reward: 306.099
# Total T: 386145 Episode Num: 457 Episode T: 969 Reward: 307.976
# Total T: 387098 Episode Num: 458 Episode T: 953 Reward: 310.258
# Total T: 388056 Episode Num: 459 Episode T: 958 Reward: 310.745
# Total T: 389033 Episode Num: 460 Episode T: 977 Reward: 308.455
# Total T: 389980 Episode Num: 461 Episode T: 947 Reward: 310.372
# Total T: 390931 Episode Num: 462 Episode T: 951 Reward: 308.388
# Total T: 391877 Episode Num: 463 Episode T: 946 Reward: 307.341
# Total T: 392867 Episode Num: 464 Episode T: 990 Reward: 304.352
# Total T: 393825 Episode Num: 465 Episode T: 958 Reward: 307.895
# Total T: 394777 Episode Num: 466 Episode T: 952 Reward: 308.431
# Total T: 395716 Episode Num: 467 Episode T: 939 Reward: 309.581
# Total T: 396653 Episode Num: 468 Episode T: 937 Reward: 309.891
# Total T: 397591 Episode Num: 469 Episode T: 938 Reward: 310.386
# Total T: 398539 Episode Num: 470 Episode T: 948 Reward: 311.233
# Total T: 399463 Episode Num: 471 Episode T: 924 Reward: 309.836
# Total T: 400390 Episode Num: 472 Episode T: 927 Reward: 308.543
# Total T: 401328 Episode Num: 473 Episode T: 938 Reward: 309.797
# Total T: 402254 Episode Num: 474 Episode T: 926 Reward: 311.217
# Total T: 403171 Episode Num: 475 Episode T: 917 Reward: 310.807
# Total T: 404085 Episode Num: 476 Episode T: 914 Reward: 310.166
# Total T: 404985 Episode Num: 477 Episode T: 900 Reward: 311.138
# Total T: 405914 Episode Num: 478 Episode T: 929 Reward: 309.719
# Total T: 406828 Episode Num: 479 Episode T: 914 Reward: 311.655
# Total T: 407744 Episode Num: 480 Episode T: 916 Reward: 312.486
# Total T: 408642 Episode Num: 481 Episode T: 898 Reward: 311.169
# Total T: 409548 Episode Num: 482 Episode T: 906 Reward: 313.544
# Total T: 410471 Episode Num: 483 Episode T: 923 Reward: 310.940
# Total T: 411377 Episode Num: 484 Episode T: 906 Reward: 311.312
# Total T: 412291 Episode Num: 485 Episode T: 914 Reward: 311.320
# Total T: 413182 Episode Num: 486 Episode T: 891 Reward: 312.924
# Total T: 414090 Episode Num: 487 Episode T: 908 Reward: 311.929
# Total T: 415018 Episode Num: 488 Episode T: 928 Reward: 310.484
# Total T: 415944 Episode Num: 489 Episode T: 926 Reward: 311.312
# Total T: 416876 Episode Num: 490 Episode T: 932 Reward: 310.784
# Total T: 417811 Episode Num: 491 Episode T: 935 Reward: 309.892
# Total T: 418712 Episode Num: 492 Episode T: 901 Reward: 313.353
# Total T: 419600 Episode Num: 493 Episode T: 888 Reward: 311.192
# Total T: 420491 Episode Num: 494 Episode T: 891 Reward: 312.481
# Total T: 421394 Episode Num: 495 Episode T: 903 Reward: 311.836
# Total T: 422279 Episode Num: 496 Episode T: 885 Reward: 313.921
# Total T: 423149 Episode Num: 497 Episode T: 870 Reward: 313.171
# Total T: 424037 Episode Num: 498 Episode T: 888 Reward: 313.893
# Total T: 424916 Episode Num: 499 Episode T: 879 Reward: 314.350
# Total T: 425821 Episode Num: 500 Episode T: 905 Reward: 311.909
# Total T: 426707 Episode Num: 501 Episode T: 886 Reward: 313.236
# Total T: 427584 Episode Num: 502 Episode T: 877 Reward: 312.280
# Total T: 428481 Episode Num: 503 Episode T: 897 Reward: 312.929
# Total T: 429344 Episode Num: 504 Episode T: 863 Reward: 313.828
# Total T: 430214 Episode Num: 505 Episode T: 870 Reward: 313.925
# Total T: 431071 Episode Num: 506 Episode T: 857 Reward: 313.473
# Total T: 431965 Episode Num: 507 Episode T: 894 Reward: 311.551
# Total T: 432876 Episode Num: 508 Episode T: 911 Reward: 312.593
# Total T: 433761 Episode Num: 509 Episode T: 885 Reward: 311.992
# Total T: 434611 Episode Num: 510 Episode T: 850 Reward: 313.752
# Total T: 435489 Episode Num: 511 Episode T: 878 Reward: 311.833
# Total T: 436348 Episode Num: 512 Episode T: 859 Reward: 314.777
# Total T: 437235 Episode Num: 513 Episode T: 887 Reward: 314.457
# Total T: 438133 Episode Num: 514 Episode T: 898 Reward: 315.526
# Total T: 439020 Episode Num: 515 Episode T: 887 Reward: 313.426
# Total T: 439893 Episode Num: 516 Episode T: 873 Reward: 313.733
# Total T: 440773 Episode Num: 517 Episode T: 880 Reward: 312.304
# Total T: 441638 Episode Num: 518 Episode T: 865 Reward: 313.255
# Total T: 442498 Episode Num: 519 Episode T: 860 Reward: 313.402
# Total T: 443342 Episode Num: 520 Episode T: 844 Reward: 313.541
# Total T: 444211 Episode Num: 521 Episode T: 869 Reward: 313.726
# Total T: 445077 Episode Num: 522 Episode T: 866 Reward: 313.986
# Total T: 445957 Episode Num: 523 Episode T: 880 Reward: 313.114
# Total T: 446498 Episode Num: 524 Episode T: 541 Reward: 82.024
# Total T: 447350 Episode Num: 525 Episode T: 852 Reward: 314.609
# Total T: 448225 Episode Num: 526 Episode T: 875 Reward: 313.539
# Total T: 449002 Episode Num: 527 Episode T: 777 Reward: 159.296
# Total T: 449868 Episode Num: 528 Episode T: 866 Reward: 313.808
# Total T: 450735 Episode Num: 529 Episode T: 867 Reward: 313.537
# Total T: 451601 Episode Num: 530 Episode T: 866 Reward: 314.085
# Total T: 452487 Episode Num: 531 Episode T: 886 Reward: 313.264
# Total T: 453370 Episode Num: 532 Episode T: 883 Reward: 313.190
# Total T: 454244 Episode Num: 533 Episode T: 874 Reward: 313.923
# Total T: 455107 Episode Num: 534 Episode T: 863 Reward: 314.558
# Total T: 455956 Episode Num: 535 Episode T: 849 Reward: 314.258
# Total T: 456817 Episode Num: 536 Episode T: 861 Reward: 314.131
# Total T: 457684 Episode Num: 537 Episode T: 867 Reward: 314.524
# Total T: 458536 Episode Num: 538 Episode T: 852 Reward: 314.742
# Total T: 459384 Episode Num: 539 Episode T: 848 Reward: 314.337
# Total T: 460220 Episode Num: 540 Episode T: 836 Reward: 315.149
# Total T: 461123 Episode Num: 541 Episode T: 903 Reward: 310.247
# Total T: 461976 Episode Num: 542 Episode T: 853 Reward: 313.899
# Total T: 462837 Episode Num: 543 Episode T: 861 Reward: 313.918
# Total T: 463702 Episode Num: 544 Episode T: 865 Reward: 314.103
# Total T: 464564 Episode Num: 545 Episode T: 862 Reward: 314.552
# Total T: 465409 Episode Num: 546 Episode T: 845 Reward: 314.518
# Total T: 466286 Episode Num: 547 Episode T: 877 Reward: 311.712
# Total T: 467148 Episode Num: 548 Episode T: 862 Reward: 312.605
# Total T: 467993 Episode Num: 549 Episode T: 845 Reward: 314.592
# Total T: 468850 Episode Num: 550 Episode T: 857 Reward: 314.887
# Total T: 469720 Episode Num: 551 Episode T: 870 Reward: 314.282
# Total T: 470557 Episode Num: 552 Episode T: 837 Reward: 314.323
# Total T: 471399 Episode Num: 553 Episode T: 842 Reward: 312.144
# Total T: 472259 Episode Num: 554 Episode T: 860 Reward: 314.413
# Total T: 473145 Episode Num: 555 Episode T: 886 Reward: 312.406
# Total T: 473984 Episode Num: 556 Episode T: 839 Reward: 314.863
# Total T: 474793 Episode Num: 557 Episode T: 809 Reward: 314.015
# Total T: 475614 Episode Num: 558 Episode T: 821 Reward: 315.789
# Total T: 476462 Episode Num: 559 Episode T: 848 Reward: 315.291
# Total T: 477311 Episode Num: 560 Episode T: 849 Reward: 313.917
# Total T: 478157 Episode Num: 561 Episode T: 846 Reward: 315.504
# Total T: 479006 Episode Num: 562 Episode T: 849 Reward: 315.278
# Total T: 479472 Episode Num: 563 Episode T: 466 Reward: 47.489
# Total T: 480312 Episode Num: 564 Episode T: 840 Reward: 314.409
# Total T: 481172 Episode Num: 565 Episode T: 860 Reward: 313.067
# Total T: 482008 Episode Num: 566 Episode T: 836 Reward: 314.971
# Total T: 482852 Episode Num: 567 Episode T: 844 Reward: 315.554
# Total T: 483694 Episode Num: 568 Episode T: 842 Reward: 315.569
# Total T: 484560 Episode Num: 569 Episode T: 866 Reward: 313.217
# Total T: 485402 Episode Num: 570 Episode T: 842 Reward: 315.226
# Total T: 486258 Episode Num: 571 Episode T: 856 Reward: 315.777
# Total T: 487115 Episode Num: 572 Episode T: 857 Reward: 312.587
# Total T: 487980 Episode Num: 573 Episode T: 865 Reward: 314.814
# Total T: 488654 Episode Num: 574 Episode T: 674 Reward: 127.971
# Total T: 489507 Episode Num: 575 Episode T: 853 Reward: 315.036
# Total T: 490376 Episode Num: 576 Episode T: 869 Reward: 314.118
# Total T: 491221 Episode Num: 577 Episode T: 845 Reward: 313.903
# Total T: 492067 Episode Num: 578 Episode T: 846 Reward: 314.860
# Total T: 492915 Episode Num: 579 Episode T: 848 Reward: 315.868
# Total T: 493779 Episode Num: 580 Episode T: 864 Reward: 314.293
# Total T: 494630 Episode Num: 581 Episode T: 851 Reward: 314.211
# Total T: 495464 Episode Num: 582 Episode T: 834 Reward: 314.109
# Total T: 496313 Episode Num: 583 Episode T: 849 Reward: 313.860
# Total T: 497169 Episode Num: 584 Episode T: 856 Reward: 315.517
# Total T: 498033 Episode Num: 585 Episode T: 864 Reward: 311.287
# Total T: 498883 Episode Num: 586 Episode T: 850 Reward: 314.899
# Total T: 499738 Episode Num: 587 Episode T: 855 Reward: 314.331
# Total T: 500563 Episode Num: 588 Episode T: 825 Reward: 313.830
# Total T: 501401 Episode Num: 589 Episode T: 838 Reward: 314.406
# Total T: 501689 Episode Num: 590 Episode T: 288 Reward: -15.941
# Total T: 502523 Episode Num: 591 Episode T: 834 Reward: 315.915
# Total T: 503372 Episode Num: 592 Episode T: 849 Reward: 314.273
# Total T: 504227 Episode Num: 593 Episode T: 855 Reward: 315.534
# Total T: 505089 Episode Num: 594 Episode T: 862 Reward: 315.635
# Total T: 505920 Episode Num: 595 Episode T: 831 Reward: 315.439
# Total T: 506740 Episode Num: 596 Episode T: 820 Reward: 315.432
# Total T: 507562 Episode Num: 597 Episode T: 822 Reward: 316.622
# Total T: 508411 Episode Num: 598 Episode T: 849 Reward: 315.767
# Total T: 509249 Episode Num: 599 Episode T: 838 Reward: 315.552
# Total T: 509489 Episode Num: 600 Episode T: 240 Reward: -41.478
# Total T: 510299 Episode Num: 601 Episode T: 810 Reward: 313.125
# Total T: 511131 Episode Num: 602 Episode T: 832 Reward: 315.211
# Total T: 511960 Episode Num: 603 Episode T: 829 Reward: 314.959
# Total T: 512797 Episode Num: 604 Episode T: 837 Reward: 314.203
# Total T: 513648 Episode Num: 605 Episode T: 851 Reward: 314.682
# Total T: 514498 Episode Num: 606 Episode T: 850 Reward: 316.162
# Total T: 515355 Episode Num: 607 Episode T: 857 Reward: 314.419
# Total T: 516198 Episode Num: 608 Episode T: 843 Reward: 314.925
# Total T: 517034 Episode Num: 609 Episode T: 836 Reward: 313.923
# Total T: 517876 Episode Num: 610 Episode T: 842 Reward: 315.806
# Total T: 518710 Episode Num: 611 Episode T: 834 Reward: 316.416
# Total T: 519571 Episode Num: 612 Episode T: 861 Reward: 315.795
# Total T: 520439 Episode Num: 613 Episode T: 868 Reward: 315.433
# Total T: 521278 Episode Num: 614 Episode T: 839 Reward: 312.533
# Total T: 522122 Episode Num: 615 Episode T: 844 Reward: 314.800
# Total T: 522948 Episode Num: 616 Episode T: 826 Reward: 315.071
# Total T: 523778 Episode Num: 617 Episode T: 830 Reward: 314.572
# Total T: 524281 Episode Num: 618 Episode T: 503 Reward: 82.712
# Total T: 525115 Episode Num: 619 Episode T: 834 Reward: 315.787
# Total T: 525946 Episode Num: 620 Episode T: 831 Reward: 314.631
# Total T: 526779 Episode Num: 621 Episode T: 833 Reward: 314.422
# Total T: 527598 Episode Num: 622 Episode T: 819 Reward: 316.073
# Total T: 528424 Episode Num: 623 Episode T: 826 Reward: 315.843
# Total T: 529243 Episode Num: 624 Episode T: 819 Reward: 317.594
# Total T: 530071 Episode Num: 625 Episode T: 828 Reward: 316.133
# Total T: 530907 Episode Num: 626 Episode T: 836 Reward: 315.446
# Total T: 531744 Episode Num: 627 Episode T: 837 Reward: 315.406
# Total T: 532561 Episode Num: 628 Episode T: 817 Reward: 317.586
# Total T: 533395 Episode Num: 629 Episode T: 834 Reward: 314.402
# Total T: 534226 Episode Num: 630 Episode T: 831 Reward: 314.587
# Total T: 535049 Episode Num: 631 Episode T: 823 Reward: 315.996
# Total T: 535768 Episode Num: 632 Episode T: 719 Reward: 165.339
# Total T: 536579 Episode Num: 633 Episode T: 811 Reward: 316.057
# Total T: 537400 Episode Num: 634 Episode T: 821 Reward: 315.171
# Total T: 537759 Episode Num: 635 Episode T: 359 Reward: 23.693
# Total T: 538278 Episode Num: 636 Episode T: 519 Reward: 71.531
# Total T: 539130 Episode Num: 637 Episode T: 852 Reward: 313.686
# Total T: 539987 Episode Num: 638 Episode T: 857 Reward: 314.399
# Total T: 540825 Episode Num: 639 Episode T: 838 Reward: 315.479
# Total T: 541660 Episode Num: 640 Episode T: 835 Reward: 314.829
# Total T: 542483 Episode Num: 641 Episode T: 823 Reward: 316.989
# Total T: 543318 Episode Num: 642 Episode T: 835 Reward: 314.802
# Total T: 544140 Episode Num: 643 Episode T: 822 Reward: 317.305
# Total T: 544978 Episode Num: 644 Episode T: 838 Reward: 313.421
# Total T: 545814 Episode Num: 645 Episode T: 836 Reward: 315.201
# Total T: 546650 Episode Num: 646 Episode T: 836 Reward: 314.817
# Total T: 547484 Episode Num: 647 Episode T: 834 Reward: 314.377
# Total T: 548299 Episode Num: 648 Episode T: 815 Reward: 312.881
# Total T: 549116 Episode Num: 649 Episode T: 817 Reward: 314.906
# Total T: 549938 Episode Num: 650 Episode T: 822 Reward: 315.370
# Total T: 550763 Episode Num: 651 Episode T: 825 Reward: 314.746
# Total T: 551592 Episode Num: 652 Episode T: 829 Reward: 315.118
# Total T: 552445 Episode Num: 653 Episode T: 853 Reward: 315.394
# Total T: 553270 Episode Num: 654 Episode T: 825 Reward: 318.154
# Total T: 554092 Episode Num: 655 Episode T: 822 Reward: 317.416
# Total T: 554932 Episode Num: 656 Episode T: 840 Reward: 315.996
# Total T: 555810 Episode Num: 657 Episode T: 878 Reward: 315.217
# Total T: 556657 Episode Num: 658 Episode T: 847 Reward: 314.680
# Total T: 557493 Episode Num: 659 Episode T: 836 Reward: 314.356
# Total T: 558345 Episode Num: 660 Episode T: 852 Reward: 314.427
# Total T: 559178 Episode Num: 661 Episode T: 833 Reward: 314.121
# Total T: 560006 Episode Num: 662 Episode T: 828 Reward: 314.227
# Total T: 560842 Episode Num: 663 Episode T: 836 Reward: 313.666
# Total T: 561666 Episode Num: 664 Episode T: 824 Reward: 314.371
# Total T: 562483 Episode Num: 665 Episode T: 817 Reward: 314.130
# Total T: 563304 Episode Num: 666 Episode T: 821 Reward: 315.611
# Total T: 564126 Episode Num: 667 Episode T: 822 Reward: 313.755
# Total T: 564940 Episode Num: 668 Episode T: 814 Reward: 314.397
# Total T: 565749 Episode Num: 669 Episode T: 809 Reward: 314.688
# Total T: 566547 Episode Num: 670 Episode T: 798 Reward: 315.446
# Total T: 567361 Episode Num: 671 Episode T: 814 Reward: 316.265
# Total T: 568158 Episode Num: 672 Episode T: 797 Reward: 316.121
# Total T: 568962 Episode Num: 673 Episode T: 804 Reward: 316.217
# Total T: 569787 Episode Num: 674 Episode T: 825 Reward: 314.301
# Total T: 570607 Episode Num: 675 Episode T: 820 Reward: 313.613
# Total T: 571417 Episode Num: 676 Episode T: 810 Reward: 313.017
# Total T: 572251 Episode Num: 677 Episode T: 834 Reward: 314.860
# Total T: 572794 Episode Num: 678 Episode T: 543 Reward: 86.907
# Total T: 573608 Episode Num: 679 Episode T: 814 Reward: 315.100
# Total T: 574407 Episode Num: 680 Episode T: 799 Reward: 315.935
# Total T: 575224 Episode Num: 681 Episode T: 817 Reward: 316.548
# Total T: 576041 Episode Num: 682 Episode T: 817 Reward: 315.577
# Total T: 576824 Episode Num: 683 Episode T: 783 Reward: 314.867
# Total T: 577624 Episode Num: 684 Episode T: 800 Reward: 315.450
# Total T: 578429 Episode Num: 685 Episode T: 805 Reward: 314.330
# Total T: 579235 Episode Num: 686 Episode T: 806 Reward: 314.475
# Total T: 580062 Episode Num: 687 Episode T: 827 Reward: 313.986
# Total T: 580870 Episode Num: 688 Episode T: 808 Reward: 314.768
# Total T: 581645 Episode Num: 689 Episode T: 775 Reward: 185.921
# Total T: 582431 Episode Num: 690 Episode T: 786 Reward: 315.804
# Total T: 583213 Episode Num: 691 Episode T: 782 Reward: 316.423
# Total T: 584010 Episode Num: 692 Episode T: 797 Reward: 317.053
# Total T: 584834 Episode Num: 693 Episode T: 824 Reward: 314.614
# Total T: 585638 Episode Num: 694 Episode T: 804 Reward: 316.552
# Total T: 586451 Episode Num: 695 Episode T: 813 Reward: 316.309
# Total T: 587233 Episode Num: 696 Episode T: 782 Reward: 314.722
# Total T: 588038 Episode Num: 697 Episode T: 805 Reward: 313.888
# Total T: 588734 Episode Num: 698 Episode T: 696 Reward: 146.396
# Total T: 589527 Episode Num: 699 Episode T: 793 Reward: 315.061
# Total T: 589980 Episode Num: 700 Episode T: 453 Reward: 60.879
# Total T: 590787 Episode Num: 701 Episode T: 807 Reward: 314.092
# Total T: 591612 Episode Num: 702 Episode T: 825 Reward: 316.517
# Total T: 592401 Episode Num: 703 Episode T: 789 Reward: 201.963
# Total T: 593167 Episode Num: 704 Episode T: 766 Reward: 315.924
# Total T: 593944 Episode Num: 705 Episode T: 777 Reward: 316.031
# Total T: 594752 Episode Num: 706 Episode T: 808 Reward: 315.682
# Total T: 595536 Episode Num: 707 Episode T: 784 Reward: 317.798
# Total T: 596303 Episode Num: 708 Episode T: 767 Reward: 318.290
# Total T: 597066 Episode Num: 709 Episode T: 763 Reward: 316.045
# Total T: 597846 Episode Num: 710 Episode T: 780 Reward: 318.271
# Total T: 598625 Episode Num: 711 Episode T: 779 Reward: 317.331
# Total T: 599412 Episode Num: 712 Episode T: 787 Reward: 318.112
# Total T: 600209 Episode Num: 713 Episode T: 797 Reward: 315.430
# Total T: 600999 Episode Num: 714 Episode T: 790 Reward: 317.646
# Total T: 601788 Episode Num: 715 Episode T: 789 Reward: 315.800
# Total T: 602576 Episode Num: 716 Episode T: 788 Reward: 316.078
# Total T: 603366 Episode Num: 717 Episode T: 790 Reward: 314.959
# Total T: 604158 Episode Num: 718 Episode T: 792 Reward: 314.568
# Total T: 604649 Episode Num: 719 Episode T: 491 Reward: 82.135
# Total T: 605431 Episode Num: 720 Episode T: 782 Reward: 316.515
# Total T: 606241 Episode Num: 721 Episode T: 810 Reward: 313.732
# Total T: 607066 Episode Num: 722 Episode T: 825 Reward: 315.108
# Total T: 607855 Episode Num: 723 Episode T: 789 Reward: 315.495
# Total T: 608657 Episode Num: 724 Episode T: 802 Reward: 315.871
# Total T: 609437 Episode Num: 725 Episode T: 780 Reward: 316.315
# Total T: 610195 Episode Num: 726 Episode T: 758 Reward: 315.619
# Total T: 610952 Episode Num: 727 Episode T: 757 Reward: 317.455
# Total T: 611750 Episode Num: 728 Episode T: 798 Reward: 315.543
# Total T: 612542 Episode Num: 729 Episode T: 792 Reward: 315.003
# Total T: 613326 Episode Num: 730 Episode T: 784 Reward: 316.786
# Total T: 614127 Episode Num: 731 Episode T: 801 Reward: 315.502
# Total T: 614908 Episode Num: 732 Episode T: 781 Reward: 313.983
# Total T: 615683 Episode Num: 733 Episode T: 775 Reward: 313.498
# Total T: 616354 Episode Num: 734 Episode T: 671 Reward: 160.716
# Total T: 617119 Episode Num: 735 Episode T: 765 Reward: 315.530
# Total T: 617901 Episode Num: 736 Episode T: 782 Reward: 315.077
# Total T: 618670 Episode Num: 737 Episode T: 769 Reward: 317.342
# Total T: 619299 Episode Num: 738 Episode T: 629 Reward: 134.851
# Total T: 620099 Episode Num: 739 Episode T: 800 Reward: 315.418
# Total T: 620890 Episode Num: 740 Episode T: 791 Reward: 317.321
# Total T: 621668 Episode Num: 741 Episode T: 778 Reward: 315.412
# Total T: 622451 Episode Num: 742 Episode T: 783 Reward: 316.740
# Total T: 623231 Episode Num: 743 Episode T: 780 Reward: 314.769
# Total T: 623996 Episode Num: 744 Episode T: 765 Reward: 315.962
# Total T: 624767 Episode Num: 745 Episode T: 771 Reward: 315.453
# Total T: 625556 Episode Num: 746 Episode T: 789 Reward: 316.707
# ...
# Total T: 821611 Episode Num: 1013 Episode T: 758 Reward: 318.970
# Total T: 822362 Episode Num: 1014 Episode T: 751 Reward: 318.591
# Total T: 823109 Episode Num: 1015 Episode T: 747 Reward: 318.552
# Total T: 823848 Episode Num: 1016 Episode T: 739 Reward: 319.680
# Total T: 824601 Episode Num: 1017 Episode T: 753 Reward: 319.565
# Total T: 825372 Episode Num: 1018 Episode T: 771 Reward: 318.546
# Total T: 826125 Episode Num: 1019 Episode T: 753 Reward: 318.177
# Total T: 826780 Episode Num: 1020 Episode T: 655 Reward: 163.093
# Total T: 827183 Episode Num: 1021 Episode T: 403 Reward: 36.160
# Total T: 827926 Episode Num: 1022 Episode T: 743 Reward: 319.525
# Total T: 828674 Episode Num: 1023 Episode T: 748 Reward: 320.795
# Total T: 829415 Episode Num: 1024 Episode T: 741 Reward: 318.861
# Total T: 830151 Episode Num: 1025 Episode T: 736 Reward: 319.766
# Total T: 830874 Episode Num: 1026 Episode T: 723 Reward: 319.878
# Total T: 831621 Episode Num: 1027 Episode T: 747 Reward: 318.806
# Total T: 832399 Episode Num: 1028 Episode T: 778 Reward: 318.768
# Total T: 833180 Episode Num: 1029 Episode T: 781 Reward: 318.943
# Total T: 833931 Episode Num: 1030 Episode T: 751 Reward: 319.185
# Total T: 834694 Episode Num: 1031 Episode T: 763 Reward: 317.932
# Total T: 835454 Episode Num: 1032 Episode T: 760 Reward: 316.844
# Total T: 836193 Episode Num: 1033 Episode T: 739 Reward: 320.182
# Total T: 836952 Episode Num: 1034 Episode T: 759 Reward: 319.689
# Total T: 837684 Episode Num: 1035 Episode T: 732 Reward: 319.874
# Total T: 838421 Episode Num: 1036 Episode T: 737 Reward: 317.342
# Total T: 838826 Episode Num: 1037 Episode T: 405 Reward: 55.331
# Total T: 839465 Episode Num: 1038 Episode T: 639 Reward: 151.991
# Total T: 839824 Episode Num: 1039 Episode T: 359 Reward: 30.179
# Total T: 840565 Episode Num: 1040 Episode T: 741 Reward: 305.656
# Total T: 841323 Episode Num: 1041 Episode T: 758 Reward: 318.675
# Total T: 842096 Episode Num: 1042 Episode T: 773 Reward: 318.526
# Total T: 842843 Episode Num: 1043 Episode T: 747 Reward: 318.235
# Total T: 843609 Episode Num: 1044 Episode T: 766 Reward: 318.166
# Total T: 844369 Episode Num: 1045 Episode T: 760 Reward: 318.330
# Total T: 845123 Episode Num: 1046 Episode T: 754 Reward: 318.487
# Total T: 845859 Episode Num: 1047 Episode T: 736 Reward: 318.282
# Total T: 846601 Episode Num: 1048 Episode T: 742 Reward: 318.822
# Total T: 847341 Episode Num: 1049 Episode T: 740 Reward: 320.414
# Total T: 848072 Episode Num: 1050 Episode T: 731 Reward: 319.631
# Total T: 848818 Episode Num: 1051 Episode T: 746 Reward: 318.523
# Total T: 849566 Episode Num: 1052 Episode T: 748 Reward: 318.123
# Total T: 850318 Episode Num: 1053 Episode T: 752 Reward: 318.660
# Total T: 851054 Episode Num: 1054 Episode T: 736 Reward: 319.910
# Total T: 851805 Episode Num: 1055 Episode T: 751 Reward: 317.987
# Total T: 852562 Episode Num: 1056 Episode T: 757 Reward: 317.751
# Total T: 853324 Episode Num: 1057 Episode T: 762 Reward: 317.329
# Total T: 854061 Episode Num: 1058 Episode T: 737 Reward: 317.744
# Total T: 854794 Episode Num: 1059 Episode T: 733 Reward: 319.516
# Total T: 855508 Episode Num: 1060 Episode T: 714 Reward: 320.871
# Total T: 856238 Episode Num: 1061 Episode T: 730 Reward: 317.916
# Total T: 856977 Episode Num: 1062 Episode T: 739 Reward: 318.556
# Total T: 857739 Episode Num: 1063 Episode T: 762 Reward: 317.781
# Total T: 858497 Episode Num: 1064 Episode T: 758 Reward: 317.818
# Total T: 859232 Episode Num: 1065 Episode T: 735 Reward: 318.762
# Total T: 859968 Episode Num: 1066 Episode T: 736 Reward: 318.082
# Total T: 860704 Episode Num: 1067 Episode T: 736 Reward: 318.282
# Total T: 861321 Episode Num: 1068 Episode T: 617 Reward: 159.541
# Total T: 862047 Episode Num: 1069 Episode T: 726 Reward: 320.445
# Total T: 862657 Episode Num: 1070 Episode T: 610 Reward: 152.831
# Total T: 863394 Episode Num: 1071 Episode T: 737 Reward: 320.735
# Total T: 864129 Episode Num: 1072 Episode T: 735 Reward: 319.738
# Total T: 864869 Episode Num: 1073 Episode T: 740 Reward: 319.222
# Total T: 865615 Episode Num: 1074 Episode T: 746 Reward: 318.938
# Total T: 866370 Episode Num: 1075 Episode T: 755 Reward: 319.090
# Total T: 867129 Episode Num: 1076 Episode T: 759 Reward: 319.416
# Total T: 867866 Episode Num: 1077 Episode T: 737 Reward: 319.663
# Total T: 868605 Episode Num: 1078 Episode T: 739 Reward: 319.063
# Total T: 869337 Episode Num: 1079 Episode T: 732 Reward: 317.452
# Total T: 870079 Episode Num: 1080 Episode T: 742 Reward: 319.645
# Total T: 870830 Episode Num: 1081 Episode T: 751 Reward: 319.986
# Total T: 871604 Episode Num: 1082 Episode T: 774 Reward: 318.272
# Total T: 872365 Episode Num: 1083 Episode T: 761 Reward: 318.117
# Total T: 873108 Episode Num: 1084 Episode T: 743 Reward: 319.042
# Total T: 873838 Episode Num: 1085 Episode T: 730 Reward: 319.473
# Total T: 874558 Episode Num: 1086 Episode T: 720 Reward: 320.880
# Total T: 875336 Episode Num: 1087 Episode T: 778 Reward: 318.179
# Total T: 876098 Episode Num: 1088 Episode T: 762 Reward: 319.841
# Total T: 876859 Episode Num: 1089 Episode T: 761 Reward: 319.354
# Total T: 877439 Episode Num: 1090 Episode T: 580 Reward: 126.305
# Total T: 878194 Episode Num: 1091 Episode T: 755 Reward: 319.728
# Total T: 878947 Episode Num: 1092 Episode T: 753 Reward: 318.885
# Total T: 879701 Episode Num: 1093 Episode T: 754 Reward: 320.268
# Total T: 880450 Episode Num: 1094 Episode T: 749 Reward: 319.748
# Total T: 881191 Episode Num: 1095 Episode T: 741 Reward: 318.914
# Total T: 881932 Episode Num: 1096 Episode T: 741 Reward: 320.294
# Total T: 882669 Episode Num: 1097 Episode T: 737 Reward: 319.463
# Total T: 883385 Episode Num: 1098 Episode T: 716 Reward: 320.721
# Total T: 884129 Episode Num: 1099 Episode T: 744 Reward: 319.298
# Total T: 884868 Episode Num: 1100 Episode T: 739 Reward: 320.146
# Total T: 885622 Episode Num: 1101 Episode T: 754 Reward: 317.993
# Total T: 886401 Episode Num: 1102 Episode T: 779 Reward: 317.228
# Total T: 887158 Episode Num: 1103 Episode T: 757 Reward: 319.178
# Total T: 887897 Episode Num: 1104 Episode T: 739 Reward: 319.277
# Total T: 888663 Episode Num: 1105 Episode T: 766 Reward: 318.526
# Total T: 889414 Episode Num: 1106 Episode T: 751 Reward: 319.448
# Total T: 890157 Episode Num: 1107 Episode T: 743 Reward: 319.409
# Total T: 890894 Episode Num: 1108 Episode T: 737 Reward: 320.188
# Total T: 891653 Episode Num: 1109 Episode T: 759 Reward: 320.130
# Total T: 892413 Episode Num: 1110 Episode T: 760 Reward: 318.860
# Total T: 893159 Episode Num: 1111 Episode T: 746 Reward: 319.767
# Total T: 893899 Episode Num: 1112 Episode T: 740 Reward: 321.728
# Total T: 894653 Episode Num: 1113 Episode T: 754 Reward: 319.631
# Total T: 895436 Episode Num: 1114 Episode T: 783 Reward: 317.286
# Total T: 896194 Episode Num: 1115 Episode T: 758 Reward: 319.772
# Total T: 896928 Episode Num: 1116 Episode T: 734 Reward: 319.540
# Total T: 897665 Episode Num: 1117 Episode T: 737 Reward: 319.706
# Total T: 898411 Episode Num: 1118 Episode T: 746 Reward: 319.269
# Total T: 899157 Episode Num: 1119 Episode T: 746 Reward: 320.306
# Total T: 899909 Episode Num: 1120 Episode T: 752 Reward: 319.273
# Total T: 900685 Episode Num: 1121 Episode T: 776 Reward: 318.659
# Total T: 901407 Episode Num: 1122 Episode T: 722 Reward: 320.329
# Total T: 902142 Episode Num: 1123 Episode T: 735 Reward: 319.680
# Total T: 902871 Episode Num: 1124 Episode T: 729 Reward: 319.579
# Total T: 903601 Episode Num: 1125 Episode T: 730 Reward: 319.654
# Total T: 904332 Episode Num: 1126 Episode T: 731 Reward: 320.920
# Total T: 905066 Episode Num: 1127 Episode T: 734 Reward: 321.286
# Total T: 905801 Episode Num: 1128 Episode T: 735 Reward: 320.569
# Total T: 906520 Episode Num: 1129 Episode T: 719 Reward: 320.623
# Total T: 907257 Episode Num: 1130 Episode T: 737 Reward: 319.408
# Total T: 907989 Episode Num: 1131 Episode T: 732 Reward: 321.113
# Total T: 908733 Episode Num: 1132 Episode T: 744 Reward: 320.593
# Total T: 909471 Episode Num: 1133 Episode T: 738 Reward: 318.828
# Total T: 910205 Episode Num: 1134 Episode T: 734 Reward: 320.464
# Total T: 910971 Episode Num: 1135 Episode T: 766 Reward: 319.667
# Total T: 911722 Episode Num: 1136 Episode T: 751 Reward: 320.591
# Total T: 912491 Episode Num: 1137 Episode T: 769 Reward: 319.207
# Total T: 913238 Episode Num: 1138 Episode T: 747 Reward: 319.809
# Total T: 913966 Episode Num: 1139 Episode T: 728 Reward: 321.377
# Total T: 914713 Episode Num: 1140 Episode T: 747 Reward: 319.782
# Total T: 915453 Episode Num: 1141 Episode T: 740 Reward: 319.389
# Total T: 916194 Episode Num: 1142 Episode T: 741 Reward: 317.154
# Total T: 916949 Episode Num: 1143 Episode T: 755 Reward: 318.831
# Total T: 917692 Episode Num: 1144 Episode T: 743 Reward: 319.630
# Total T: 918446 Episode Num: 1145 Episode T: 754 Reward: 319.027
# Total T: 919171 Episode Num: 1146 Episode T: 725 Reward: 321.270
# Total T: 919909 Episode Num: 1147 Episode T: 738 Reward: 320.313
# Total T: 920660 Episode Num: 1148 Episode T: 751 Reward: 317.333
# Total T: 921414 Episode Num: 1149 Episode T: 754 Reward: 320.008
# Total T: 922151 Episode Num: 1150 Episode T: 737 Reward: 319.114
# Total T: 922902 Episode Num: 1151 Episode T: 751 Reward: 319.688
# Total T: 923627 Episode Num: 1152 Episode T: 725 Reward: 321.040
# Total T: 924357 Episode Num: 1153 Episode T: 730 Reward: 320.939
# Total T: 925092 Episode Num: 1154 Episode T: 735 Reward: 320.349
# Total T: 925841 Episode Num: 1155 Episode T: 749 Reward: 321.059
# Total T: 926589 Episode Num: 1156 Episode T: 748 Reward: 320.636
# Total T: 927337 Episode Num: 1157 Episode T: 748 Reward: 320.404
# Total T: 928080 Episode Num: 1158 Episode T: 743 Reward: 319.753
# Total T: 928831 Episode Num: 1159 Episode T: 751 Reward: 318.854
# Total T: 929564 Episode Num: 1160 Episode T: 733 Reward: 320.686
# Total T: 930290 Episode Num: 1161 Episode T: 726 Reward: 320.420
# Total T: 931024 Episode Num: 1162 Episode T: 734 Reward: 320.476
# Total T: 931752 Episode Num: 1163 Episode T: 728 Reward: 321.211
# Total T: 932503 Episode Num: 1164 Episode T: 751 Reward: 321.266
# Total T: 933253 Episode Num: 1165 Episode T: 750 Reward: 319.037
# Total T: 933997 Episode Num: 1166 Episode T: 744 Reward: 319.702
# Total T: 934721 Episode Num: 1167 Episode T: 724 Reward: 320.006
# Total T: 935455 Episode Num: 1168 Episode T: 734 Reward: 320.156
# Total T: 936196 Episode Num: 1169 Episode T: 741 Reward: 321.605
# Total T: 936926 Episode Num: 1170 Episode T: 730 Reward: 322.343
# Total T: 937686 Episode Num: 1171 Episode T: 760 Reward: 319.617
# Total T: 938432 Episode Num: 1172 Episode T: 746 Reward: 321.835
# Total T: 939169 Episode Num: 1173 Episode T: 737 Reward: 322.157
# Total T: 939588 Episode Num: 1174 Episode T: 419 Reward: 67.241
# Total T: 940308 Episode Num: 1175 Episode T: 720 Reward: 320.494
# Total T: 941045 Episode Num: 1176 Episode T: 737 Reward: 320.605
# Total T: 941807 Episode Num: 1177 Episode T: 762 Reward: 320.248
# Total T: 942538 Episode Num: 1178 Episode T: 731 Reward: 320.590
# Total T: 943279 Episode Num: 1179 Episode T: 741 Reward: 321.047
# Total T: 944018 Episode Num: 1180 Episode T: 739 Reward: 319.791
# Total T: 944745 Episode Num: 1181 Episode T: 727 Reward: 320.582
# Total T: 945222 Episode Num: 1182 Episode T: 477 Reward: 91.296
# Total T: 945954 Episode Num: 1183 Episode T: 732 Reward: 318.856
# Total T: 946714 Episode Num: 1184 Episode T: 760 Reward: 318.097
# Total T: 947442 Episode Num: 1185 Episode T: 728 Reward: 320.105
# Total T: 948166 Episode Num: 1186 Episode T: 724 Reward: 319.539
# Total T: 948886 Episode Num: 1187 Episode T: 720 Reward: 320.525
# Total T: 949596 Episode Num: 1188 Episode T: 710 Reward: 322.033
# Total T: 950327 Episode Num: 1189 Episode T: 731 Reward: 320.728
# Total T: 951047 Episode Num: 1190 Episode T: 720 Reward: 321.415
# Total T: 951771 Episode Num: 1191 Episode T: 724 Reward: 320.725
# Total T: 952491 Episode Num: 1192 Episode T: 720 Reward: 319.813
# Total T: 953204 Episode Num: 1193 Episode T: 713 Reward: 320.644
# Total T: 953907 Episode Num: 1194 Episode T: 703 Reward: 321.757
# Total T: 954635 Episode Num: 1195 Episode T: 728 Reward: 321.068
# Total T: 955353 Episode Num: 1196 Episode T: 718 Reward: 322.255
# Total T: 956086 Episode Num: 1197 Episode T: 733 Reward: 320.769
# Total T: 956821 Episode Num: 1198 Episode T: 735 Reward: 320.037
# Total T: 957559 Episode Num: 1199 Episode T: 738 Reward: 319.984
# Total T: 958304 Episode Num: 1200 Episode T: 745 Reward: 321.241
# Total T: 959049 Episode Num: 1201 Episode T: 745 Reward: 318.134
# Total T: 959795 Episode Num: 1202 Episode T: 746 Reward: 320.991
# Total T: 960534 Episode Num: 1203 Episode T: 739 Reward: 319.911
# Total T: 960832 Episode Num: 1204 Episode T: 298 Reward: 3.284
# Total T: 961589 Episode Num: 1205 Episode T: 757 Reward: 320.156
# Total T: 962317 Episode Num: 1206 Episode T: 728 Reward: 320.692
# Total T: 963032 Episode Num: 1207 Episode T: 715 Reward: 322.291
# Total T: 963776 Episode Num: 1208 Episode T: 744 Reward: 317.700
# Total T: 964487 Episode Num: 1209 Episode T: 711 Reward: 322.216
# Total T: 965215 Episode Num: 1210 Episode T: 728 Reward: 323.455
# Total T: 965621 Episode Num: 1211 Episode T: 406 Reward: 59.001
# Total T: 966351 Episode Num: 1212 Episode T: 730 Reward: 321.708
# Total T: 967090 Episode Num: 1213 Episode T: 739 Reward: 322.148
# Total T: 967826 Episode Num: 1214 Episode T: 736 Reward: 320.886
# Total T: 968568 Episode Num: 1215 Episode T: 742 Reward: 320.605
# Total T: 969314 Episode Num: 1216 Episode T: 746 Reward: 320.411
# Total T: 970062 Episode Num: 1217 Episode T: 748 Reward: 320.447
# Total T: 970793 Episode Num: 1218 Episode T: 731 Reward: 320.794
# Total T: 971525 Episode Num: 1219 Episode T: 732 Reward: 322.001
# Total T: 972250 Episode Num: 1220 Episode T: 725 Reward: 322.020
# Total T: 972979 Episode Num: 1221 Episode T: 729 Reward: 321.872
# Total T: 973726 Episode Num: 1222 Episode T: 747 Reward: 320.595
# Total T: 974466 Episode Num: 1223 Episode T: 740 Reward: 321.975
# Total T: 975202 Episode Num: 1224 Episode T: 736 Reward: 321.232
# Total T: 975940 Episode Num: 1225 Episode T: 738 Reward: 322.446
# Total T: 976665 Episode Num: 1226 Episode T: 725 Reward: 322.190
# Total T: 977393 Episode Num: 1227 Episode T: 728 Reward: 322.025
# Total T: 978138 Episode Num: 1228 Episode T: 745 Reward: 321.657
# Total T: 978874 Episode Num: 1229 Episode T: 736 Reward: 322.439
# Total T: 979600 Episode Num: 1230 Episode T: 726 Reward: 321.765
# Total T: 980340 Episode Num: 1231 Episode T: 740 Reward: 320.762
# Total T: 981073 Episode Num: 1232 Episode T: 733 Reward: 322.908
# Total T: 981803 Episode Num: 1233 Episode T: 730 Reward: 321.387
# Total T: 982528 Episode Num: 1234 Episode T: 725 Reward: 322.404
# Total T: 983279 Episode Num: 1235 Episode T: 751 Reward: 319.678
# Total T: 984027 Episode Num: 1236 Episode T: 748 Reward: 322.284
# Total T: 984775 Episode Num: 1237 Episode T: 748 Reward: 320.765
# Total T: 985526 Episode Num: 1238 Episode T: 751 Reward: 322.367
# Total T: 986270 Episode Num: 1239 Episode T: 744 Reward: 322.074
# Total T: 987012 Episode Num: 1240 Episode T: 742 Reward: 322.731
# Total T: 987715 Episode Num: 1241 Episode T: 703 Reward: 323.346
# Total T: 988430 Episode Num: 1242 Episode T: 715 Reward: 321.969
# Total T: 989159 Episode Num: 1243 Episode T: 729 Reward: 321.630
# Total T: 989893 Episode Num: 1244 Episode T: 734 Reward: 322.335
# Total T: 990619 Episode Num: 1245 Episode T: 726 Reward: 321.182
# Total T: 991359 Episode Num: 1246 Episode T: 740 Reward: 322.188
# Total T: 992107 Episode Num: 1247 Episode T: 748 Reward: 321.727
# Total T: 992598 Episode Num: 1248 Episode T: 491 Reward: 104.355
# Total T: 993312 Episode Num: 1249 Episode T: 714 Reward: 322.148
# Total T: 994043 Episode Num: 1250 Episode T: 731 Reward: 317.780
# Total T: 994764 Episode Num: 1251 Episode T: 721 Reward: 321.497
# Total T: 995490 Episode Num: 1252 Episode T: 726 Reward: 319.908
# Total T: 996248 Episode Num: 1253 Episode T: 758 Reward: 321.369
# Total T: 996988 Episode Num: 1254 Episode T: 740 Reward: 321.505
# Total T: 997704 Episode Num: 1255 Episode T: 716 Reward: 322.784
# Total T: 998438 Episode Num: 1256 Episode T: 734 Reward: 321.477
# Total T: 999171 Episode Num: 1257 Episode T: 733 Reward: 321.446
# Total T: 999589 Episode Num: 1258 Episode T: 418 Reward: 65.156
